# %%
import nsepython
from portfoliotools.screener.stock_detail import StockDetail
import pandas as pd
from pandas.plotting import register_matplotlib_converters
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import numpy as np
from datetime import datetime

warnings.filterwarnings("ignore")
register_matplotlib_converters()
# %matplotlib inline
sns.set()
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
ticker = 'NIFTY'
focus_period = 1000
lookback_period = 30
return_period = 1 # Daily returns

# %%
stockObj = StockDetail(ticker, period = focus_period)
prices = stockObj.calculate_return(return_period) # return_period Returns
prices['Risk'] = prices['Return'].rolling( window = lookback_period).std()*np.sqrt(360/return_period) # return_period Risk
prices['Return'] = prices['Return']*(360/return_period)

# %%
fig = make_subplots(rows = 2, cols = 1, shared_xaxes= True, vertical_spacing = 0.08, 
column_widths = [15], row_heights = [2,2])
# Add Returns
fig.add_trace(
go.Scatter(x=prices.index, y=prices['Return']/360, name="Return", line = {'color':'purple'}), row = 1, col =1,
)
fig.add_trace(
go.Scatter(x=prices.index, y=[prices['Return'].mean()/360]*len(prices), name="Avg Return", line = {'color':'skyblue'}), row = 1, col =1,
)
# Add Risk
fig.add_trace(
go.Scatter(x=prices.index, y=prices['Risk'], name="Risk", line = {'color':'red'}), row = 2, col =1,
)
fig.add_trace(
go.Scatter(x=prices.index, y=[prices['Risk'].mean()]*len(prices), name="Avg Risk", line = {'color':'pink'}), row = 2, col =1,
)

fig['layout']['yaxis1'].update(title='Return')
fig['layout']['yaxis2'].update(title='Risk')
fig.show()
print("Avg Return : " + str(round(prices['Return'].mean(),3)))
print("Avg Risk : " + str(round(prices['Risk'].mean(),3)))
print("Latest Risk : " + str(round(prices['Risk'].values[-1],3)))
# Out:
# <div>                            <div id="97e0b38a-5cae-466a-8ca5-673bf0c23c27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97e0b38a-5cae-466a-8ca5-673bf0c23c27")) {                    Plotly.newPlot(                        "97e0b38a-5cae-466a-8ca5-673bf0c23c27",                        [{"line": {"color": "purple"}, "name": "Return", "type": "scatter", "x": ["2018-09-25", "2018-09-26", "2018-09-27", "2018-09-28", "2018-10-01", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-12", "2018-10-15", "2018-10-16", "2018-10-17", "2018-10-19", "2018-10-22", "2018-10-23", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-29", "2018-10-30", "2018-10-31", "2018-11-01", "2018-11-02", "2018-11-05", "2018-11-06", "2018-11-07", "2018-11-09", "2018-11-12", "2018-11-13", "2018-11-14", "2018-11-15", "2018-11-16", "2018-11-19", "2018-11-20", "2018-11-21", "2018-11-22", "2018-11-26", "2018-11-27", "2018-11-28", "2018-11-29", "2018-11-30", "2018-12-03", "2018-12-04", "2018-12-05", "2018-12-06", "2018-12-07", "2018-12-10", "2018-12-11", "2018-12-12", "2018-12-13", "2018-12-14", "2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-24", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-31", "2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-22", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-15", "2019-04-16", "2019-04-18", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-30", "2019-05-02", "2019-05-03", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-03", "2019-06-04", "2019-06-06", "2019-06-07", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-13", "2019-08-14", "2019-08-16", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-09", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09 ...
# Avg Return : 22.797
# Avg Risk : 22.695
# Latest Risk : 13.258

# %%
fnoList = nsepython.fnolist()
details = nsepython.nse_fno(ticker)
option_chain = nsepython.option_chain(ticker)
fnoPrice = [z['metadata'] for z in details['stocks']]
fnoPrice = pd.DataFrame(fnoPrice)
optionPrice = fnoPrice[fnoPrice['instrumentType'] == 'Stock Options']
futurePrice = fnoPrice[fnoPrice['instrumentType'] == 'Stock Futures']
expiryDates = optionPrice['expiryDate'].unique()
strikePrices = optionPrice['strikePrice'].unique()
info = details['info']
info['underlying'] = details['underlyingValue']

# %%
result = []
for data in option_chain['records']['data']:
    pe = data.get('PE', None)
    ce = data.get('CE', None)
    if pe is not None:
        result.append({
            'strikePrice': data.get('strikePrice',0),
            'expiryDate': data.get('expiryDate', ''),
            'optionType': 'Put',
            'closePrice': pe.get('lastPrice', 0),
            'totalBuyQuantity': pe.get('totalBuyQuantity', 0),
            'totalSellQuantity' : pe.get('totalSellQuantity', 0),
            'openInterest' : pe.get('openInterest', 0),
            'pchangeinOpenInterest' : pe.get('pchangeinOpenInterest', 0),
            'identifier' : pe.get('identifier', ''),
            'numberOfContractsTraded' : pe.get('totalTradedVolume', 0),
            'impliedVolatility' : pe.get('impliedVolatility', 0),
            'pChange' : pe.get('pChange', 0),
            'underlyingValue' : pe.get('underlyingValue', 0),
        })
    if ce is not None:
        result.append({
            'strikePrice': data.get('strikePrice',0),
            'expiryDate': data.get('expiryDate', ''),
            'optionType': 'Call',
            'closePrice': ce.get('lastPrice', 0),
            'totalBuyQuantity': ce.get('totalBuyQuantity', 0),
            'totalSellQuantity' : ce.get('totalSellQuantity', 0),
            'openInterest' : ce.get('openInterest', 0),
            'pchangeinOpenInterest' : ce.get('pchangeinOpenInterest', 0),
            'identifier' : ce.get('identifier', ''),
            'numberOfContractsTraded' : ce.get('totalTradedVolume', 0),
            'impliedVolatility' : ce.get('impliedVolatility', 0),
            'pChange' : ce.get('pChange', 0),
            'underlyingValue' : ce.get('underlyingValue', 0),
        })
option_chain = pd.DataFrame(result)
option_chain['expiryDate'] = option_chain['expiryDate'].apply(lambda x: datetime.strptime(x, '%d-%b-%Y').strftime('%Y-%m-%d'))
option_chain
# Out:
#       strikePrice  expiryDate optionType  closePrice  totalBuyQuantity  \
# 0            6000  2021-06-24        Put        0.80             14925
# 1            7500  2022-12-29        Put      235.00              5250
# 2            7600  2022-12-29        Put       80.00               750
# 3            8000  2021-12-30        Put        3.10              6975
# 4            8100  2021-06-24        Put        0.25              4500
# 5            8200  2021-06-24        Put        0.50              4650
# 6            8300  2022-06-30        Put       93.75              5400
# 7            8300  2021-06-24        Put        3.05              4650
# 8            8400  2021-06-24        Put        0.05              4875
# 9            8500  2022-12-29        Put      105.00              5250
# 10           8500  2021-12-30        Put        6.00              3600
# 11           8500  2021-06-24        Put        0.40             28050
# 12           8600  2021-06-24        Put        5.65              8625
# 13           8700  2022-12-29        Put      109.00              5250
# 14           8700  2021-06-24        Put      162.00              4650
# 15           8800  2021-06-24        Put        0.55              6525
# 16           9000  2021-12-30        Put       15.35              5325
# 17           9000  2021-12-30       Call     6750.00               600
# 18           9000  2021-06-24        Put        0.50             55950
# 19           9000  2022-12-29        Put       76.00              4875
# 20           9100  2021-06-24        Put      156.00              4650
# 21           9100  2021-12-30        Put      410.00              5250
# 22           9200  2021-06-24        Put      226.00              4650
# 23           9200  2021-12-30        Put       53.25              5250
# 24           9500  2022-12-29        Put      105.05              5550
# 25           9500  2021-06-24        Put        0.50             44550
# 26           9700  2021-12-30        Put      156.75              5250
# 27           9700  2022-12-29        Put      114.55              3750
# 28           9700  2021-06-24        Put       82.00              4650
# 29           9900  2022-12-29        Put      664.70              3750
# 30           9900  2022-06-30        Put       98.00              5325
# 31          10000  2023-06-29        Put      113.95                 0
# 32          10000  2022-06-30        Put       57.00              5325
# 33          10000  2021-12-30        Put       24.00              8025
# 34          10000  2021-12-30       Call     5625.25              1050
# 35          10000  2021-06-24        Put        0.25            113250
# 36          10000  2021-06-24       Call     5690.00             11175
# 37          10000  2022-12-29        Put      109.00              4800
# 38          10100  2021-06-24        Put        1.70              7500
# 39          10100  2021-06-24       Call     3946.00              7500
# 40          10100  2021-12-30        Put       71.90              5250
# 41          10200  2021-06-24        Put      171.60              7350
# 42          10200  2021-12-30        Put     1385.00              5250
# 43          10300  2021-06-24        Put        3.00              7575
# 44          10300  2021-06-24       Call     3758.00              7200
# 45          10300  2021-12-30        Put      745.45              5250
# 46          10400  2021-06-24        Put        0.55              8100
# 47          10400  2021-06-24       Call     4539.00              7200
# 48          10400  2021-12-30        Put       36.00              5250
# 49          10500  2022-12-29        Put      120.00               225
# 50          10500  2023-06-29        Put      256.40                 0
# 51          10500  2021-06-24        Put        0.20             22425
# 52          10500  2021-06-24       Call     5062.15              7050
# 53          10500  2021-12-30        Put       24.10             12450
# 54          10500  2021-12-30       Call     4145.00              1200
# 55          10500  2022-06-30        Put       90.00              4800
# 56          10500  2021-09-30        Put       60.90              9375
# 57          10600  2021-12-30        Put       63.90              5250
# 58          10600  2021-12-30       Call     4250.00               525
# 59          10600  2021-06-24        Put        2.85             12450
# 60          10600  2021-06-24       Call     5080.00             10425
# 61          10700  2021-06-24        Put        1.35              8100
# 62          10700  2021-06-24       Call     5055.00              7125
# 63          10700  2021-12-30        Put       64.15              5250
# 64          10700  2021-12-30       Call     4150.00               525
# 65          10800  2021-06-24        Put        1.05              8100
# 66          10800  2021-06-24       Call     4750.00              7275
# 67          10800  2021-12-30        Put       66.30              5250
# 68          10800  2021-12-30       Call     2341.30               750
# 69          10800  2022-06-30        Put       94.75                75
# 70          10900  2021-06-24        Put        0.20             10425
# 71          10900  2021-06-24       Call     3770.00             10425
# 72          10900  2021-12-30        Put      120.05              3225
# 73          11000  2022-06-30        Put      135.00              1500
# 74          11000  2022-12-29        Put      125.00                 0
# 75          11000  2023-06-29        Put      166.00              3225
# 76          11000  2021-06-24        Put        0.40             33675
# 77          11000  2021-06-24       Call     4620.00             10800
# 78          11000  2021-09-30        Put       13.10             11625
# 79          11000  2021-09-30       Call     4638.80               975
# 80          11000  2021-12-30        Put       35.00             27975
# 81          11000  2021-12-30       Call     4645.00              2550
# 82          11100  2021-06-24        Put        2.60              4275
# 83          11100  2021-12-30        Put       79.95               750
# 84          11200  2021-06-24        Put        0.35              9525
# 85          11200  2021-06-24       Call     4650.00              7200
# 86          11300  2021-06-24        Put        1.00              4050
# 87          11300  2021-06-24       Call     4340.00             10200
# 88          11300  2022-06-30        Put      194.95                75
# 89          11300  2021-12-30        Put     1927.00               750
# 90          11400  2021-12-30        Put       45.00               750
# 91          11400  2021-06-24        Put        0.65              5025
# 92          11400  2021-06-24       Call     3900.00              7125
# 93          11500  2022-12-29        Put      362.35                 0
# 94          11500  2022-12-29       Call     3874.25              1050
# 95          11500  2021-12-30        Put       38.05             14400
# 96          11500  2021-12-30       Call     4411.30              2700
# 97          11500  2021-09-30        Put        7.50             11175
# 98          11500  2021-09-30       Call     4140.00              1050
# 99          11500  2021-06-24        Put        0.55             31500
# 100         11500  2021-06-24       Call     4079.90             10650
# 101         11500  2022-06-30        Put      125.00                 0
# 102         11600  2021-06-24        Put        0.80             14325
# 103         11600  2021-06-24       Call     4100.00              7125
# 104         11600  2021-12-30        Put      739.45               750
# 105         11600  2021-12-30       Call     2650.00               525
# 106         11700  2022-06-30        Put      200.00                 0
# 107         11700  2021-12-30        Put       60.00               750
# 108         11700  2021-12-30       Call     2480.25               750
# 109         11700  2021-06-24        Put        0.75              8250
# 110         11700  2021-06-24       Call     4100.00              7125
# 111         11800  2021-12-30       Call     2261.15               900
# 112         11800  2021-06-24       Call     3920.00               750
# 113         11900  2021-06-24        Put        0.40             12675
# 114         11900  2021-06-24       Call     3112.05             10200
# 115         11900  2021-12-30       Call     1048.10               750
# 116         12000  2022-06-30        Put      225.90                 0
# 117         12000  2022-12-29        Put      272.95                 0
# 118         12000  2022-03-31        Put        0.00                 0
# 119         12000  2022-03-31       Call        0.00               225
# 120         12000  2021-09-30        Put       26.95             16050
# 121         12000  2021-09-30       Call        0.00               975
# 122         12000  2021-06-24        Put        0.45             76500
# 123         12000  2021-06-24       Call     3660.15             12000
# 124         12000  2021-12-30        Put       47.90             22650
# 125         12000  2021-12-30       Call     3788.35              3300
# 126         12100  2023-06-29        Put      323.00                 0
# 127         12100  2021-06-24       Call     2185.00                75
# 128         12200  2021-12-30        Put       80.00               750
# 129         12200  2021-06-24       Call     3330.00                75
# 130         12300  2021-12-30        Put     1897.95               750
# 131         12400  2021-06-24        Put        0.60             55125
# 132         12400  2021-12-30        Put      110.00               750
# 133         12500  2022-03-31        Put        0.00                 0
# 134         12500  2022-03-31       Call        0.00               225
# 135         12500  2022-12-29        Put      395.25                 0
# 136         12500  2021-12-30        Put       56.00             13125
# 137         12500  2021-12-30       Call     3400.00              2625
# 138         12500  2021-06-24        Put        0.45             75900
# 139         12500  2021-06-24       Call     3154.55             11700
# 140         12500  2022-06-30        Put      225.00                 0
# 141         12500  2021-09-30        Put       30.00              1800
# 142         12500  2021-09-30       Call        0.00               975
# 143         12700  2021-06-24        Put        0.50             86700
# 144         12700  2021-12-30        Put     1743.00               750
# 145         12800  2021-06-24        Put        0.25            182625
# 146         12800  2021-06-24       Call     2755.00             13875
# 147         12850  2021-06-24        Put        0.40             49950
# 148         12850  2021-06-24       Call        0.00             10350
# 149         12850  2021-07-01        Put        0.00              7200
# 150         12850  2021-07-01       Call        0.00              9000
# 151         12900  2021-07-01        Put        0.00              7200
# 152         12900  2021-07-01       Call        0.00              9000
# 153         12900  2021-06-24        Put        0.45             95700
# 154         12900  2021-06-24       Call     2758.35             10275
# 155         12950  2021-06-24        Put        0.30             51675
# 156         12950  2021-06-24       Call        0.00             10200
# 157         12950  2021-07-01        Put        0.00              7200
# 158         12950  2021-07-01       Call        0.00              9000
# 159         13000  2021-07-29        Put        6.75             20750
# 160         13000  2021-07-29       Call     2755.25              9350
# 161         13000  2021-09-30        Put       41.95              2775
# 162         13000  2021-09-30       Call     2850.00              2175
# 163         13000  2021-12-30        Put       71.50             20925
# 164         13000  2021-12-30       Call     2850.00              3600
# 165         13000  2022-03-31        Put        0.00                 0
# 166         13000  2022-03-31       Call        0.00               225
# 167         13000  2021-06-24        Put        0.50            187200
# 168         13000  2021-06-24       Call     2726.75             20625
# 169         13000  2022-12-29        Put      639.30                 0
# 170         13000  2021-07-01        Put        0.00             18975
# 171         13000  2021-07-01       Call        0.00              9000
# 172         13000  2022-06-30        Put      352.85                 0
# 173         13050  2021-07-01        Put        0.00              7200
# 174         13050  2021-07-01       Call        0.00              9000
# 175         13050  2021-06-24        Put        0.80             47175
# 176         13050  2021-06-24       Call        0.00             12750
# 177         13050  2021-07-29        Put        0.00              5900
# 178         13050  2021-07-29       Call        0.00             10200
# 179         13100  2021-07-29        Put       10.00              9200
# 180         13100  2021-07-29       Call     2474.85              9000
# 181         13100  2021-06-24        Put        0.75             71175
# 182         13100  2021-06-24       Call     2474.35             10425
# 183         13100  2021-07-01        Put        0.00             18900
# 184         13100  2021-07-01       Call        0.00              9000
# 185         13150  2021-07-29        Put        5.05              6450
# 186         13150  2021-07-29       Call     2586.20              9300
# 187         13150  2021-06-24        Put        1.20             50100
# 188         13150  2021-06-24       Call        0.00              9750
# 189         13150  2021-07-01        Put        0.00             12000
# 190         13150  2021-07-01       Call        0.00              9000
# 191         13200  2021-07-29        Put        7.95             31550
# 192         13200  2021-07-29       Call     2425.00             10150
# 193         13200  2021-06-24        Put        0.70             59550
# 194         13200  2021-06-24       Call     2362.00             13200
# 195         13200  2021-07-01        Put        0.00             20400
# 196         13200  2021-07-01       Call        0.00              9000
# 197         13200  2021-07-15        Put       14.60              5175
# 198         13200  2021-07-15       Call        0.00              4800
# 199         13200  2021-07-08        Put        0.00               300
# 200         13200  2021-07-08       Call        0.00              4800
# 201         13250  2021-07-29        Put        0.00              5900
# 202         13250  2021-07-29       Call        0.00              8950
# 203         13250  2021-07-15        Put        4.00               525
# 204         13250  2021-07-15       Call        0.00              4800
# 205         13250  2021-06-24        Put        0.85             49275
# 206         13250  2021-06-24       Call        0.00              9525
# 207         13250  2021-07-01        Put        0.00              7200
# 208         13250  2021-07-01       Call        0.00              9000
# 209         13250  2021-07-08       Call        0.00              4800
# 210         13300  2021-07-29        Put       11.50             10950
# 211         13300  2021-07-29       Call        0.00              9000
# 212         13300  2021-07-01        Put        2.95             18150
# 213         13300  2021-07-01       Call        0.00              9000
# 214         13300  2021-06-24        Put        1.00             59025
# 215         13300  2021-06-24       Call     2542.70             10425
# 216         13300  2021-07-08        Put        0.00              2700
# 217         13300  2021-07-08       Call        0.00              4800
# 218         13300  2021-07-15        Put       12.50              9450
# 219         13300  2021-07-15       Call        0.00              4800
# 220         13350  2021-07-29        Put        0.00              5900
# 221         13350  2021-07-29       Call        0.00             10150
# 222         13350  2021-07-15        Put       11.70              5250
# 223         13350  2021-07-15       Call        0.00              4800
# 224         13350  2021-07-08       Call        0.00              4800
# 225         13350  2021-06-24        Put        1.05             45150
# 226         13350  2021-06-24       Call        0.00              9825
# 227         13350  2021-07-01        Put        0.00             12000
# 228         13350  2021-07-01       Call        0.00              9000
# 229         13400  2021-06-24        Put        1.05             74325
# 293         13650  2021-06-24        Put        4.10             30750
# 294         13650  2021-06-24       Call        0.00              9825
# 295         13650  2021-07-29        Put        0.00              1100
# 296         13650  2021-07-29       Call        0.00             10150
# 297         13650  2021-07-15       Call        0.00              4800
# 298         13650  2021-07-01        Put        0.00                 0
# 299         13650  2021-07-01       Call        0.00              9000
# 300         13650  2021-07-22       Call        0.00              4800
# 301         13700  2021-07-15        Put        0.00              1500
# 302         13700  2021-07-15       Call        0.00              4800
# 303         13700  2021-07-29        Put       14.85             11050
# 304         13700  2021-07-29       Call     1956.00             10250
# 305         13700  2021-07-08        Put        0.00              3300
# 306         13700  2021-07-08       Call        0.00              4800
# 307         13700  2021-07-22        Put        0.00              2100
# 308         13700  2021-07-22       Call        0.00              4800
# 309         13700  2021-07-01        Put        8.00             31200
# 310         13700  2021-07-01       Call        0.00              9000
# 311         13700  2021-06-24        Put        1.50             84825
# 312         13700  2021-06-24       Call     2049.35             12300
# 313         13750  2021-06-24        Put        1.95             35325
# 314         13750  2021-06-24       Call     1642.00             12825
# 315         13750  2021-07-22       Call        0.00              4800
# 316         13750  2021-07-29        Put        0.00              1100
# 317         13750  2021-07-29       Call        0.00             10150
# 318         13750  2021-07-01        Put       16.50                 0
# 319         13750  2021-07-01       Call        0.00              9000
# 320         13750  2021-07-08       Call        0.00              4800
# 321         13750  2021-07-15        Put        0.00              4950
# 322         13750  2021-07-15       Call        0.00              4800
# 323         13800  2021-07-08        Put        0.00              3600
# 324         13800  2021-07-08       Call        0.00              4800
# 325         13800  2021-07-15        Put        0.00              1500
# 326         13800  2021-07-15       Call        0.00              4800
# 327         13800  2021-07-22        Put        0.00              2400
# 328         13800  2021-07-22       Call        0.00              4800
# 329         13800  2021-07-29        Put       12.05             17100
# 330         13800  2021-07-29       Call     1952.95              8850
# 331         13800  2021-06-24        Put        1.50             70800
# 332         13800  2021-06-24       Call     1748.30             10950
# 333         13800  2021-07-01        Put        0.00             31200
# 334         13800  2021-07-01       Call        0.00              9000
# 335         13850  2021-07-08        Put        0.00                 0
# 336         13850  2021-07-08       Call        0.00              4800
# 337         13850  2021-06-24        Put        1.35             49125
# 338         13850  2021-06-24       Call     1752.25              9450
# 339         13850  2021-07-22       Call        0.00              4800
# 340         13850  2021-07-29        Put        0.00              1100
# 341         13850  2021-07-29       Call        0.00             10150
# 342         13850  2021-08-26        Put        0.00              5400
# 343         13850  2021-08-26       Call        0.00              5100
# 344         13850  2021-07-01        Put       18.60              4875
# 345         13850  2021-07-01       Call        0.00              9000
# 346         13850  2021-07-15       Call        0.00              4800
# 347         13900  2021-07-08        Put        0.00              4050
# 348         13900  2021-07-08       Call        0.00              4800
# 349         13900  2021-07-29        Put       12.90             19150
# 350         13900  2021-07-29       Call     1869.95              9100
# 351         13900  2021-07-22        Put        0.00              1950
# 352         13900  2021-07-22       Call        0.00              4800
# 353         13900  2021-07-01        Put        0.00             12900
# 354         13900  2021-07-01       Call        0.00              9000
# 355         13900  2021-08-26        Put        0.00              2200
# 356         13900  2021-08-26       Call        0.00              5050
# 1771               0.00    0.000000         15683.35
# 1772               0.00    0.000000         15683.35
# 1773               0.00    0.000000         15683.35
# 1774               0.00    0.000000         15683.35
# 1775               0.00    0.000000         15683.35
# 1776               0.00    0.000000         15683.35
# 1777               0.00    0.000000         15683.35
# 1778               0.00    0.000000         15683.35
# 1779               0.00    0.000000         15683.35
# 1780               0.00    0.000000         15683.35
# 1781               0.00    0.000000         15683.35
# 1782               0.00    0.000000         15683.35
# 1783               0.00    0.000000         15683.35
# 1784               0.00    0.000000         15683.35

# %%
# Straddle Details

def straddleCost(data):
    try:
        callPrice = list(data[data['optionType'] == 'Call']['closePrice'].values)[0]
        putPrice = list(data[data['optionType'] == 'Put']['closePrice'].values)[0]
        return callPrice + putPrice
    except:
        return 0

def callPrice(data):
    try:
        callPrice = list(data[data['optionType'] == 'Call']['closePrice'].values)[0]
        return callPrice
    except:
        return 0
    
def putPrice(data):
    try:
        putPrice = list(data[data['optionType'] == 'Put']['closePrice'].values)[0]
        return putPrice
    except:
        return 0
    
def straddleBreakEven(data, direction = 'up', displayPercent = False):
    try:
        cost = straddleCost(data)
        strike = list(data['strikePrice'].values)[0]
        spot = list(data['underlyingValue'].values)[0]
        if direction == 'up':
            price = strike + cost
        else:
            price = strike - cost
        if displayPercent:
            if spot != 0:
                return ((price - spot)*100 / spot)
            else:
                np.nan
        else:
            return price
    except:
        return 0

def groupImpliedVolatility(data, optionType = 'Call'):
    try:
        return list(data[data['optionType'] == optionType]['impliedVolatility'].values)[0]
    except:
        return 0

straddleDetails = option_chain.groupby(['expiryDate', 'strikePrice']).agg({'numberOfContractsTraded' : sum, 'underlyingValue': max})
straddleDetails['call_price'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(callPrice)
straddleDetails['put_price'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(putPrice)
straddleDetails['cost'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(straddleCost)
straddleDetails['breakeven_up'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(straddleBreakEven,'up')
straddleDetails['breakeven_down'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(straddleBreakEven,'down')
straddleDetails['breakeven_up_per'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(straddleBreakEven,'up', True)
straddleDetails['breakeven_down_per'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(straddleBreakEven,'down', True)
straddleDetails['iv_pe'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(groupImpliedVolatility,'Put')
straddleDetails['iv_ce'] = option_chain.groupby(['expiryDate', 'strikePrice']).apply(groupImpliedVolatility,'Call')
straddleDetails = straddleDetails[straddleDetails['numberOfContractsTraded'] > 0]
straddleDetails = straddleDetails[straddleDetails['iv_ce'] > 0]
straddleDetails = straddleDetails[straddleDetails['iv_pe'] > 0]
straddleDetails
# Out:
#                         numberOfContractsTraded  underlyingValue  call_price  \
# expiryDate strikePrice
# 2021-06-24 13000                          17031         15683.35     2726.75
#            13600                           1906         15683.35     2106.05
#            13700                           1705         15683.35     2049.35
#            14000                          44079         15683.35     1728.25
#            14050                            103         15683.35     1657.90
#            14150                            407         15683.35     1612.55
#            14200                          10518         15683.35     1510.00
#            14300                          22436         15683.35     1433.25
#            14450                           3091         15683.35     1306.55
#            14500                         112468         15683.35     1231.00
#            14600                          62647         15683.35     1130.00
#            14700                          82245         15683.35     1032.55
#            14800                         131521         15683.35      927.15
#            15000                         386427         15683.35      735.10
#            15050                          45291         15683.35      687.20
#            15100                         186673         15683.35      635.00
#            16200                7.349833           -0.761317  15.64  11.41
#            16250                7.939311           -0.713177  16.79  11.42
#            16300                8.294465           -0.430712  15.99  11.35
#            16400               10.282880           -1.143888  24.66  11.20
#            16500               10.327194            0.087035  16.65  11.19
#            16600               12.469275           -0.779808  26.44  11.20
#            16700               13.343450           -0.378746  24.99  11.33
#            17000               16.258644            0.531774  20.52  12.71
#            17100               17.715284            0.350372  23.95  13.28
#            17200               18.914964            0.425929  24.52  13.47
# 2021-08-26 15300                3.199253           -8.087877  16.59   8.27
#            15400                3.521250           -7.134636  16.68   8.52
#            15500                4.128263           -6.466412  16.72  10.56
#            15600                4.704352           -5.767263  17.01  11.29
#            15700                5.054086           -4.841759  16.45  11.07
#            15800                5.695849           -4.208285  16.74  11.47
#            15900                6.270344           -3.507541  16.97  11.19
#            16000                6.881502           -2.843461  16.56  11.46
#            16100                7.950151           -2.636873  18.44  11.78
#            16300                9.415399           -1.551646  18.28  11.61
#            16500               10.945684           -0.531455  17.33  11.44
#            17000               16.158538            0.631880  19.26  11.13
# 2021-09-30 15500                5.136658           -7.474806  17.94   7.00
#            16000                7.843350           -3.805309  17.36   9.92
# 2021-12-30 16000               10.193294           -6.155254  19.03   7.61
#            16500               13.151846           -2.737617  19.30   7.99
#            17000               17.011353           -0.220935  19.89   8.09
#            17500               22.596575            0.570031  23.64   8.66

# %%
expiryDates = list(set(straddleDetails.index.get_level_values(0)))
expiryDates.sort()
rows = round(len(expiryDates)/2)
fig = make_subplots(rows = rows, cols = 2, shared_xaxes= True, vertical_spacing = 0.08, 
                    column_widths = [15,15], row_heights = [2]*rows)
i=1
j=1
for date in expiryDates:
    data = straddleDetails[straddleDetails.index.isin([date], level=0)]
    # Add iv_ce
    fig.add_trace(
    go.Scatter(x=data.index.get_level_values(1), y=data['iv_ce'], name="IV CE", line = {'color':'green'}), row = i, col =j,
    )
    # Add iv_pe
    fig.add_trace(
    go.Scatter(x=data.index.get_level_values(1), y=data['iv_pe'], name="IV PE", line = {'color':'red'}), row = i, col =j,
    )

    fig['layout']['yaxis' + str(2*(i-1)+j)].update(title=date)
    if j == 2:
        i+=1
    j = 1 if j==2 else 2

fig.show()
# Out:
# <div>                            <div id="5fb19769-3971-49c6-9e11-8e01ce1b642d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fb19769-3971-49c6-9e11-8e01ce1b642d")) {                    Plotly.newPlot(                        "5fb19769-3971-49c6-9e11-8e01ce1b642d",                        [{"line": {"color": "green"}, "name": "IV CE", "type": "scatter", "x": [13000, 13600, 13700, 14000, 14050, 14150, 14200, 14300, 14450, 14500, 14600, 14700, 14800, 15000, 15050, 15100, 15200, 15250, 15300, 15350, 15400, 15450, 15500, 15550, 15600, 15650, 15700, 15750, 15800, 15850, 15900, 15950, 16350, 16400, 16550, 16650, 16750, 16800, 16900, 17200, 17250, 17500], "xaxis": "x", "y": [82.47, 38.49, 72.91, 54.75, 35.25, 63.17, 35.78, 48.44, 51.74, 41.75, 38.48, 36.53, 31.68, 28.39, 27.43, 25.29, 22.16, 21.37, 20.05, 18.89, 17.3, 16.43, 15.34, 14.7, 14.04, 13.73, 13.36, 13.05, 12.68, 12.64, 12.39, 12.19, 15.53, 16.17, 18.67, 20.06, 20.79, 22.06, 23.05, 28.03, 27.24, 32.0], "yaxis": "y"}, {"line": {"color": "red"}, "name": "IV PE", "type": "sc
# %%
nsepython.nse_fno('NIFTY')
# Out:
# {'info': {'symbol': 'NIFTY',
#   'companyName': 'NIFTY',
#   'identifier': 'none',
#   'activeSeries': [],
#   'debtSeries': [],
#   'isFNOSec': True,
#   'isCASec': False,
#   'isSLBSec': False,
#   'isDebtSec': False,
#   'isSuspended': False},
#  'filter': {'expiryDate': 'Invalid date', 'strikePrice': ''},
#  'underlyingValue': 15683.35,
#  'vfq': 5001,
#  'fut_timestamp': '18-Jun-2021 15:30:03',
#  'opt_timestamp': '18-Jun-2021 15:30:08',
#  'stocks': [{'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15700,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15700.00',
#     'openPrice': 112.05,
#     'highPrice': 149.7,
#     'lowPrice': 60.5,
#     'closePrice': 98.4,
#     'prevClose': 118.45,
#     'lastPrice': 111.8,
#     'change': -6.650000000000006,
#     'pChange': -5.6141831996623095,
#     'numberOfContractsTraded': 1044903,
#     'totalTurnover': 66659.59},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 281400,
#     'totalSellQuantity': 305550,
#     'bid': [{'price': 111.8, 'quantity': 75},
#      {'price': 111.05, 'quantity': 1275},
#      {'price': 111, 'quantity': 2250},
#      {'price': 110.6, 'quantity': 300},
#      {'price': 110.45, 'quantity': 900}],
#     'ask': [{'price': 112, 'quantity': 300},
#      {'price': 112.5, 'quantity': 900},
#      {'price': 112.65, 'quantity': 75},
#      {'price': 112.75, 'quantity': 75},
#      {'price': 112.9, 'quantity': 375}],
#     'carryOfCost': {'price': {'bestBuy': 111.8,
#       'bestSell': 112,
#       'lastPrice': 111.8},
#      'carry': {'bestBuy': -36088.59651575869,
#       'bestSell': -36075.54914856779,
#       'lastPrice': -36088.59651575869}},
#     'tradeInfo': {'tradedVolume': 1044903,
#      'value': 66659.59,
#      'vmap': 85.06,
#      'premiumTurnover': 12370392.411885,
#      'openInterest': 48958,
#      'changeinOpenInterest': 9121,
#      'pchangeinOpenInterest': 22.895800386575296,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.36,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15500,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15500.00',
#     'openPrice': 40.15,
#     'highPrice': 172.5,
#     'lowPrice': 28.2,
#     'closePrice': 43.15,
#     'prevClose': 56.55,
#     'lastPrice': 28.35,
#     'change': -28.199999999999996,
#     'pChange': -49.86737400530504,
#     'numberOfContractsTraded': 980715,
#     'totalTurnover': 59401.91},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 294300,
#     'totalSellQuantity': 354225,
#     'bid': [{'price': 28.3, 'quantity': 300},
#      {'price': 28.25, 'quantity': 75},
#      {'price': 28.15, 'quantity': 75},
#      {'price': 28.1, 'quantity': 75},
#      {'price': 28.05, 'quantity': 75}],
#     'ask': [{'price': 28.95, 'quantity': 75},
#      {'price': 29.5, 'quantity': 375},
#      {'price': 29.95, 'quantity': 150},
#      {'price': 30, 'quantity': 1650},
#      {'price': 30.05, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 28.3,
#       'bestSell': 28.95,
#       'lastPrice': 28.35},
#      'carry': {'bestBuy': -46117.69973508288,
#       'bestSell': -45951.92841968325,
#       'lastPrice': -46104.813588753525}},
#     'tradeInfo': {'tradedVolume': 980715,
#      'value': 59401.91,
#      'vmap': 80.76,
#      'premiumTurnover': 11460213.78255,
#      'openInterest': 50760,
#      'changeinOpenInterest': 9611,
#      'pchangeinOpenInterest': 23.356582176966633,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.54,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15600,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15600.00',
#     'openPrice': 83.7,
#     'highPrice': 228,
#     'lowPrice': 45.9,
#     'closePrice': 70,
#     'prevClose': 85.15,
#     'lastPrice': 48.85,
#     'change': -36.300000000000004,
#     'pChange': -42.63065179095714,
#     'numberOfContractsTraded': 909293,
#     'totalTurnover': 74757.52},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 157050,
#     'totalSellQuantity': 366375,
#     'bid': [{'price': 47.7, 'quantity': 150},
#      {'price': 47.5, 'quantity': 150},
#      {'price': 47, 'quantity': 3750},
#      {'price': 45.5, 'quantity': 75},
#      {'price': 45.1, 'quantity': 300}],
#     'ask': [{'price': 49.5, 'quantity': 975},
#      {'price': 49.8, 'quantity': 150},
#      {'price': 49.9, 'quantity': 150},
#      {'price': 50, 'quantity': 2250},
#      {'price': 50.1, 'quantity': 225}],
#     'carryOfCost': {'price': {'bestBuy': 47.7,
#       'bestSell': 49.5,
#       'lastPrice': 48.85},
#      'carry': {'bestBuy': 0.28741945495550536,
#       'bestSell': -42036.190421127074,
#       'lastPrice': -42132.6839460538}},
#     'tradeInfo': {'tradedVolume': 909293,
#      'value': 74757.52,
#      'vmap': 109.62,
#      'premiumTurnover': 10713485.623995,
#      'openInterest': 38087,
#      'changeinOpenInterest': 12125,
#      'pchangeinOpenInterest': 46.70287343039828,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 11.68,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15800,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15800.00',
#     'openPrice': 81,
#     'highPrice': 87.9,
#     'lowPrice': 33.7,
#     'closePrice': 56.2,
#     'prevClose': 72.6,
#     'lastPrice': 63,
#     'change': -9.599999999999994,
#     'pChange': -13.22314049586776,
#     'numberOfContractsTraded': 802093,
#     'totalTurnover': 30655.99},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 286950,
#     'totalSellQuantity': 547350,
#     'bid': [{'price': 63, 'quantity': 75},
#      {'price': 62, 'quantity': 450},
#      {'price': 61.95, 'quantity': 300},
#      {'price': 61.85, 'quantity': 375},
#      {'price': 61.65, 'quantity': 300}],
#     'ask': [{'price': 63.5, 'quantity': 75},
#      {'price': 63.65, 'quantity': 375},
#      {'price': 64, 'quantity': 2775},
#      {'price': 64.1, 'quantity': 150},
#      {'price': 64.15, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 63,
#       'bestSell': 63.5,
#       'lastPrice': 63},
#      'carry': {'bestBuy': -40275.70740636379,
#       'bestSell': -40217.99959596187,
#       'lastPrice': -40275.70740636379}},
#     'tradeInfo': {'tradedVolume': 802093,
#      'value': 30655.99,
#      'vmap': 50.96,
#      'premiumTurnover': 9535458.04446,
#      'openInterest': 52399,
#      'changeinOpenInterest': 3974,
#      'pchangeinOpenInterest': 8.206504904491482,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.68,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15600,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15600.00',
#     'openPrice': 205.15,
#     'highPrice': 205.2,
#     'lowPrice': 93.3,
#     'closePrice': 153.4,
#     'prevClose': 178.55,
#     'lastPrice': 175,
#     'change': -3.5500000000000114,
#     'pChange': -1.988238588630642,
#     'numberOfContractsTraded': 797615,
#     'totalTurnover': 74285.87},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 225600,
#     'totalSellQuantity': 112425,
#     'bid': [{'price': 175.8, 'quantity': 75},
#      {'price': 175, 'quantity': 3825},
#      {'price': 174.1, 'quantity': 2100},
#      {'price': 174, 'quantity': 375},
#      {'price': 173, 'quantity': 75}],
#     'ask': [{'price': 177.1, 'quantity': 75},
#      {'price': 177.25, 'quantity': 600},
#      {'price': 178, 'quantity': 900},
#      {'price': 178.1, 'quantity': 75},
#      {'price': 179, 'quantity': 2025}],
#     'carryOfCost': {'price': {'bestBuy': 175.8,
#       'bestSell': 177.1,
#       'lastPrice': 175},
#      'carry': {'bestBuy': -32784.35791668913,
#       'bestSell': -32730.574732063833,
#       'lastPrice': -32817.653299380334}},
#     'tradeInfo': {'tradedVolume': 797615,
#      'value': 74285.87,
#      'vmap': 124.18,
#      'premiumTurnover': 9406381.373025,
#      'openInterest': 22095,
#      'changeinOpenInterest': 6272,
#      'pchangeinOpenInterest': 39.638500916387535,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 14.04,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15400,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15400.00',
#     'openPrice': 34.7,
#     'highPrice': 126,
#     'lowPrice': 16.3,
#     'closePrice': 26.05,
#     'prevClose': 37.15,
#     'lastPrice': 16.85,
#     'change': -20.299999999999997,
#     'pChange': -54.643337819650064,
#     'numberOfContractsTraded': 618423,
#     'totalTurnover': 24985.84},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 244875,
#     'totalSellQuantity': 208725,
#     'bid': [{'price': 16.3, 'quantity': 3600},
#      {'price': 16.2, 'quantity': 4950},
#      {'price': 16.1, 'quantity': 75},
#      {'price': 16, 'quantity': 900},
#      {'price': 15.5, 'quantity': 75}],
#     'ask': [{'price': 16.85, 'quantity': 225},
#      {'price': 16.9, 'quantity': 1500},
#      {'price': 17, 'quantity': 900},
#      {'price': 17.1, 'quantity': 75},
#      {'price': 17.2, 'quantity': 300}],
#     'carryOfCost': {'price': {'bestBuy': 16.3,
#       'bestSell': 16.85,
#       'lastPrice': 16.85},
#      'carry': {'bestBuy': -50145.08562198915,
#       'bestSell': -49902.83111439388,
#       'lastPrice': -49902.83111439388}},
#     'tradeInfo': {'tradedVolume': 618423,
#      'value': 24985.84,
#      'vmap': 53.87,
#      'premiumTurnover': 7167771.4852575,
#      'openInterest': 32480,
#      'changeinOpenInterest': 3937,
#      'pchangeinOpenInterest': 13.793224258136846,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.52,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15900,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15900.00',
#     'openPrice': 52.45,
#     'highPrice': 52.45,
#     'lowPrice': 17.6,
#     'closePrice': 28.6,
#     'prevClose': 40.4,
#     'lastPrice': 32.3,
#     'change': -8.100000000000001,
#     'pChange': -20.049504950495052,
#     'numberOfContractsTraded': 583929,
#     'totalTurnover': 11793.91},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 397275,
#     'totalSellQuantity': 376725,
#     'bid': [{'price': 31, 'quantity': 1800},
#      {'price': 30.5, 'quantity': 750},
#      {'price': 30.35, 'quantity': 150},
#      {'price': 30.3, 'quantity': 75},
#      {'price': 30.2, 'quantity': 75}],
#     'ask': [{'price': 32.3, 'quantity': 1425},
#      {'price': 32.35, 'quantity': 450},
#      {'price': 32.5, 'quantity': 675},
#      {'price': 32.6, 'quantity': 1200},
#      {'price': 32.65, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 31,
#       'bestSell': 32.3,
#       'lastPrice': 32.3},
#      'carry': {'bestBuy': -45452.48431628042,
#       'bestSell': -45152.60012835313,
#       'lastPrice': -45152.60012835313}},
#     'tradeInfo': {'tradedVolume': 583929,
#      'value': 11793.91,
#      'vmap': 26.93,
#      'premiumTurnover': 6975147.2309775,
#      'openInterest': 40820,
#      'changeinOpenInterest': 5036,
#      'pchangeinOpenInterest': 14.073328862061256,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.39,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15700,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15700.00',
#     'openPrice': 114.95,
#     'highPrice': 295.55,
#     'lowPrice': 80,
#     'closePrice': 106.45,
#     'prevClose': 125.45,
#     'lastPrice': 80.95,
#     'change': -44.5,
#     'pChange': -35.47229972100438,
#     'numberOfContractsTraded': 515364,
#     'totalTurnover': 56540.58},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 171450,
#     'totalSellQuantity': 123075,
#     'bid': [{'price': 81.35, 'quantity': 150},
#      {'price': 80.7, 'quantity': 300},
#      {'price': 80, 'quantity': 4500},
#      {'price': 79.15, 'quantity': 75},
#      {'price': 79.1, 'quantity': 75}],
#     'ask': [{'price': 82.8, 'quantity': 300},
#      {'price': 84.95, 'quantity': 375},
#      {'price': 85, 'quantity': 750},
#      {'price': 85.5, 'quantity': 750},
#      {'price': 85.65, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 81.35,
#       'bestSell': 82.8,
#       'lastPrice': 80.95},
#      'carry': {'bestBuy': -38409.636823267145,
#       'bestSell': -38280.666060866126,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 515364,
#      'value': 56540.58,
#      'vmap': 146.28,
#      'premiumTurnover': 6124951.68444,
#      'openInterest': 32687,
#      'changeinOpenInterest': 3090,
#      'pchangeinOpenInterest': 10.440247322363753,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 10.65,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 16000,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE16000.00',
#     'openPrice': 23.1,
#     'highPrice': 24.65,
#     'lowPrice': 9.45,
#     'closePrice': 13.35,
#     'prevClose': 21.15,
#     'lastPrice': 14.55,
#     'change': -6.599999999999998,
#     'pChange': -31.205673758865238,
#     'numberOfContractsTraded': 497758,
#     'totalTurnover': 5342.19},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 457275,
#     'totalSellQuantity': 402300,
#     'bid': [{'price': 14.5, 'quantity': 9000},
#      {'price': 14.4, 'quantity': 300},
#      {'price': 14.35, 'quantity': 750},
#      {'price': 14.25, 'quantity': 375},
#      {'price': 14.1, 'quantity': 150}],
#     'ask': [{'price': 14.6, 'quantity': 75},
#      {'price': 14.75, 'quantity': 4800},
#      {'price': 14.8, 'quantity': 2625},
#      {'price': 14.85, 'quantity': 525},
#      {'price': 14.9, 'quantity': 1575}],
#     'carryOfCost': {'price': {'bestBuy': 14.5,
#       'bestSell': 14.6,
#       'lastPrice': 14.55},
#      'carry': {'bestBuy': -50999.30576820832,
#       'bestSell': -50949.133749407665,
#       'lastPrice': -50974.176655614225}},
#     'tradeInfo': {'tradedVolume': 497758,
#      'value': 5342.19,
#      'vmap': 14.31,
#      'premiumTurnover': 5978438.187735,
#      'openInterest': 59544,
#      'changeinOpenInterest': 11987,
#      'pchangeinOpenInterest': 25.205542822297453,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.17,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15300,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15300.00',
#     'openPrice': 16.2,
#     'highPrice': 90.6,
#     'lowPrice': 9.5,
#     'closePrice': 15.8,
#     'prevClose': 25.5,
#     'lastPrice': 10.2,
#     'change': -15.3,
#     'pChange': -60,
#     'numberOfContractsTraded': 419762,
#     'totalTurnover': 11324.13},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 233775,
#     'totalSellQuantity': 161475,
#     'bid': [{'price': 10.35, 'quantity': 75},
#      {'price': 9.75, 'quantity': 450},
#      {'price': 9.5, 'quantity': 375},
#      {'price': 9.4, 'quantity': 300},
#      {'price': 9.25, 'quantity': 75}],
#     'ask': [{'price': 10.7, 'quantity': 375},
#      {'price': 10.75, 'quantity': 75},
#      {'price': 10.9, 'quantity': 450},
#      {'price': 11, 'quantity': 3300},
#      {'price': 11.1, 'quantity': 150}],
#     'carryOfCost': {'price': {'bestBuy': 10.35,
#       'bestSell': 10.7,
#       'lastPrice': 10.2},
#      'carry': {'bestBuy': 4.359716639086062,
#       'bestSell': -53217.81159630661,
#       'lastPrice': -53567.16055090335}},
#     'tradeInfo': {'tradedVolume': 419762,
#      'value': 11324.13,
#      'vmap': 35.97,
#      'premiumTurnover': 4828093.079355,
#      'openInterest': 28617,
#      'changeinOpenInterest': 4333,
#      'pchangeinOpenInterest': 17.843024213473893,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 14.53,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15750,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15750.00',
#     'openPrice': 89,
#     'highPrice': 112,
#     'lowPrice': 45.9,
#     'closePrice': 75.8,
#     'prevClose': 93.7,
#     'lastPrice': 85.7,
#     'change': -8,
#     'pChange': -8.537886872998932,
#     'numberOfContractsTraded': 404835,
#     'totalTurnover': 20622.29},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 139725,
#     'totalSellQuantity': 253125,
#     'bid': [{'price': 85.25, 'quantity': 6150},
#      {'price': 85.2, 'quantity': 75},
#      {'price': 85.1, 'quantity': 4500},
#      {'price': 85, 'quantity': 7650},
#      {'price': 84.9, 'quantity': 150}],
#     'ask': [{'price': 86, 'quantity': 75},
#      {'price': 87, 'quantity': 6150},
#      {'price': 87.15, 'quantity': 600},
#      {'price': 87.2, 'quantity': 675},
#      {'price': 87.3, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 85.25,
#       'bestSell': 86,
#       'lastPrice': 85.7},
#      'carry': {'bestBuy': -38067.797661027515,
#       'bestSell': -38003.85564637138,
#       'lastPrice': -38029.365282114726}},
#     'tradeInfo': {'tradedVolume': 404835,
#      'value': 20622.29,
#      'vmap': 67.92,
#      'premiumTurnover': 4802735.7324,
#      'openInterest': 17539,
#      'changeinOpenInterest': 6537,
#      'pchangeinOpenInterest': 59.41646973277586,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.05,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15000,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15000.00',
#     'openPrice': 9,
#     'highPrice': 32.05,
#     'lowPrice': 4.95,
#     'closePrice': 6.25,
#     'prevClose': 10.75,
#     'lastPrice': 5.5,
#     'change': -5.25,
#     'pChange': -48.837209302325576,
#     'numberOfContractsTraded': 379783,
#     'totalTurnover': 3509.19},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 251250,
#     'totalSellQuantity': 288900,
#     'bid': [{'price': 5.1, 'quantity': 2850},
#      {'price': 5.05, 'quantity': 750},
#      {'price': 5, 'quantity': 5175},
#      {'price': 4.95, 'quantity': 150},
#      {'price': 4.9, 'quantity': 75}],
#     'ask': [{'price': 5.5, 'quantity': 1200},
#      {'price': 5.7, 'quantity': 675},
#      {'price': 6, 'quantity': 825},
#      {'price': 6.15, 'quantity': 1425},
#      {'price': 6.25, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 5.1,
#       'bestSell': 5.5,
#       'lastPrice': 5.5},
#      'carry': {'bestBuy': -58627.13496899094,
#       'bestSell': -58075.92983568148,
#       'lastPrice': -58075.92983568148}},
#     'tradeInfo': {'tradedVolume': 379783,
#      'value': 3509.19,
#      'vmap': 12.32,
#      'premiumTurnover': 4276067.94492,
#      'openInterest': 69993,
#      'changeinOpenInterest': 20128,
#      'pchangeinOpenInterest': 40.36498546074401,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 19.94,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15650,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15650.00',
#     'openPrice': 139.55,
#     'highPrice': 170.15,
#     'lowPrice': 75.8,
#     'closePrice': 121.95,
#     'prevClose': 146.9,
#     'lastPrice': 142,
#     'change': -4.900000000000006,
#     'pChange': -3.335602450646702,
#     'numberOfContractsTraded': 373727,
#     'totalTurnover': 28982.53},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 93000,
#     'totalSellQuantity': 57375,
#     'bid': [{'price': 141, 'quantity': 75},
#      {'price': 140.95, 'quantity': 150},
#      {'price': 139, 'quantity': 150},
#      {'price': 138.05, 'quantity': 75},
#      {'price': 136, 'quantity': 225}],
#     'ask': [{'price': 143, 'quantity': 150},
#      {'price': 143.25, 'quantity': 75},
#      {'price': 143.6, 'quantity': 450},
#      {'price': 144, 'quantity': 750},
#      {'price': 144.25, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 141,
#       'bestSell': 143,
#       'lastPrice': 142},
#      'carry': {'bestBuy': -34394.643709261356,
#       'bestSell': -34291.82510812466,
#       'lastPrice': -34343.05338853278}},
#     'tradeInfo': {'tradedVolume': 373727,
#      'value': 28982.53,
#      'vmap': 103.4,
#      'premiumTurnover': 4415603.19135,
#      'openInterest': 8941,
#      'changeinOpenInterest': 4756,
#      'pchangeinOpenInterest': 113.64396654719235,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.73,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15200,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15200.00',
#     'openPrice': 14.7,
#     'highPrice': 63.85,
#     'lowPrice': 7.5,
#     'closePrice': 11.3,
#     'prevClose': 17.55,
#     'lastPrice': 7.95,
#     'change': -9.600000000000001,
#     'pChange': -54.700854700854705,
#     'numberOfContractsTraded': 371340,
#     'totalTurnover': 6901.35},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 282150,
#     'totalSellQuantity': 124350,
#     'bid': [{'price': 7.5, 'quantity': 375},
#      {'price': 7.4, 'quantity': 600},
#      {'price': 7.2, 'quantity': 600},
#      {'price': 7, 'quantity': 975},
#      {'price': 6.9, 'quantity': 75}],
#     'ask': [{'price': 7.95, 'quantity': 375},
#      {'price': 8, 'quantity': 19500},
#      {'price': 8.2, 'quantity': 75},
#      {'price': 8.4, 'quantity': 150},
#      {'price': 8.6, 'quantity': 3000}],
#     'carryOfCost': {'price': {'bestBuy': 7.5,
#       'bestSell': 7.95,
#       'lastPrice': 7.95},
#      'carry': {'bestBuy': -55811.79885906345,
#       'bestSell': -55386.43582975843,
#       'lastPrice': -55386.43582975843}},
#     'tradeInfo': {'tradedVolume': 371340,
#      'value': 6901.35,
#      'vmap': 24.78,
#      'premiumTurnover': 4240177.3539,
#      'openInterest': 34243,
#      'changeinOpenInterest': 12688,
#      'pchangeinOpenInterest': 58.863372767339364,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 16.31,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15500,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15500.00',
#     'openPrice': 274,
#     'highPrice': 281.5,
#     'lowPrice': 136.4,
#     'closePrice': 225.75,
#     'prevClose': 248.7,
#     'lastPrice': 254,
#     'change': 5.300000000000011,
#     'pChange': 2.1310816244471296,
#     'numberOfContractsTraded': 338584,
#     'totalTurnover': 44528.03},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 119475,
#     'totalSellQuantity': 32775,
#     'bid': [{'price': 256.55, 'quantity': 75},
#      {'price': 253.05, 'quantity': 450},
#      {'price': 253, 'quantity': 75},
#      {'price': 252, 'quantity': 150},
#      {'price': 250, 'quantity': 225}],
#     'ask': [{'price': 258.25, 'quantity': 75},
#      {'price': 259, 'quantity': 2025},
#      {'price': 260, 'quantity': 225},
#      {'price': 260.05, 'quantity': 75},
#      {'price': 261, 'quantity': 150}],
#     'carryOfCost': {'price': {'bestBuy': 256.55,
#       'bestSell': 258.25,
#       'lastPrice': 254},
#      'carry': {'bestBuy': -30025.128794089775,
#       'bestSell': -29976.915720623827,
#       'lastPrice': -30098.050759786667}},
#     'tradeInfo': {'tradedVolume': 338584,
#      'value': 44528.03,
#      'vmap': 175.35,
#      'premiumTurnover': 3980567.0283,
#      'openInterest': 15715,
#      'changeinOpenInterest': 3461,
#      'pchangeinOpenInterest': 28.243838746531743,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 15.34,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15550,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15550.00',
#     'openPrice': 62,
#     'highPrice': 198.7,
#     'lowPrice': 37,
#     'closePrice': 55.3,
#     'prevClose': 70,
#     'lastPrice': 37,
#     'change': -33,
#     'pChange': -47.14285714285714,
#     'numberOfContractsTraded': 336269,
#     'totalTurnover': 24216.41},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 148875,
#     'totalSellQuantity': 106800,
#     'bid': [{'price': 37, 'quantity': 675},
#      {'price': 36.95, 'quantity': 75},
#      {'price': 36.9, 'quantity': 150},
#      {'price': 36.5, 'quantity': 75},
#      {'price': 36, 'quantity': 450}],
#     'ask': [{'price': 37.7, 'quantity': 675},
#      {'price': 37.75, 'quantity': 75},
#      {'price': 38, 'quantity': 225},
#      {'price': 38.1, 'quantity': 75},
#      {'price': 38.8, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 37,
#       'bestSell': 37.7,
#       'lastPrice': 37},
#      'carry': {'bestBuy': -44160.890146719146,
#       'bestSell': -44024.07221950804,
#       'lastPrice': -44160.890146719146}},
#     'tradeInfo': {'tradedVolume': 336269,
#      'value': 24216.41,
#      'vmap': 96.02,
#      'premiumTurnover': 3945953.624535,
#      'openInterest': 9589,
#      'changeinOpenInterest': 4255,
#      'pchangeinOpenInterest': 79.77127859017622,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.07,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15650,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15650.00',
#     'openPrice': 107.75,
#     'highPrice': 261.2,
#     'lowPrice': 62,
#     'closePrice': 88.45,
#     'prevClose': 103.7,
#     'lastPrice': 63.35,
#     'change': -40.35,
#     'pChange': -38.91031822565091,
#     'numberOfContractsTraded': 274682,
#     'totalTurnover': 24342.32},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 98400,
#     'totalSellQuantity': 53100,
#     'bid': [{'price': 63.95, 'quantity': 75},
#      {'price': 63.35, 'quantity': 75},
#      {'price': 63.2, 'quantity': 675},
#      {'price': 63.1, 'quantity': 675},
#      {'price': 63, 'quantity': 525}],
#     'ask': [{'price': 64, 'quantity': 375},
#      {'price': 64.9, 'quantity': 300},
#      {'price': 65, 'quantity': 750},
#      {'price': 65.8, 'quantity': 150},
#      {'price': 66, 'quantity': 600}],
#     'carryOfCost': {'price': {'bestBuy': 63.95,
#       'bestSell': 64,
#       'lastPrice': 63.35},
#      'carry': {'bestBuy': -40166.44975444057,
#       'bestSell': -40160.74440049638,
#       'lastPrice': -40235.2640896218}},
#     'tradeInfo': {'tradedVolume': 274682,
#      'value': 24342.32,
#      'vmap': 118.16,
#      'premiumTurnover': 3248422.29384,
#      'openInterest': 9709,
#      'changeinOpenInterest': 3182,
#      'pchangeinOpenInterest': 48.751340585261225,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 11.22,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 16100,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE16100.00',
#     'openPrice': 11.4,
#     'highPrice': 12.5,
#     'lowPrice': 5.25,
#     'closePrice': 6.35,
#     'prevClose': 10.65,
#     'lastPrice': 6.35,
#     'change': -4.300000000000001,
#     'pChange': -40.375586854460096,
#     'numberOfContractsTraded': 271443,
#     'totalTurnover': 1563.51},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 383475,
#     'totalSellQuantity': 127650,
#     'bid': [{'price': 6.35, 'quantity': 1575},
#      {'price': 6.3, 'quantity': 750},
#      {'price': 6.25, 'quantity': 1275},
#      {'price': 6.2, 'quantity': 825},
#      {'price': 6.1, 'quantity': 1275}],
#     'ask': [{'price': 6.6, 'quantity': 75},
#      {'price': 6.75, 'quantity': 75},
#      {'price': 6.8, 'quantity': 375},
#      {'price': 6.9, 'quantity': 300},
#      {'price': 7, 'quantity': 300}],
#     'carryOfCost': {'price': {'bestBuy': 6.35,
#       'bestSell': 6.6,
#       'lastPrice': 6.35},
#      'carry': {'bestBuy': -57026.87077481841,
#       'bestSell': -56744.98247108562,
#       'lastPrice': -57026.87077481841}},
#     'tradeInfo': {'tradedVolume': 271443,
#      'value': 1563.51,
#      'vmap': 7.68,
#      'premiumTurnover': 3279237.73668,
#      'openInterest': 33311,
#      'changeinOpenInterest': 3453,
#      'pchangeinOpenInterest': 11.564739768236318,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.27,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15850,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15850.00',
#     'openPrice': 62.1,
#     'highPrice': 65.05,
#     'lowPrice': 24.75,
#     'closePrice': 40.5,
#     'prevClose': 54.55,
#     'lastPrice': 46.6,
#     'change': -7.949999999999996,
#     'pChange': -14.573785517873503,
#     'numberOfContractsTraded': 269277,
#     'totalTurnover': 7627.94},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 203250,
#     'totalSellQuantity': 181725,
#     'bid': [{'price': 45, 'quantity': 2025},
#      {'price': 44.75, 'quantity': 75},
#      {'price': 44.5, 'quantity': 375},
#      {'price': 43, 'quantity': 150},
#      {'price': 42.9, 'quantity': 75}],
#     'ask': [{'price': 46.6, 'quantity': 150},
#      {'price': 46.75, 'quantity': 150},
#      {'price': 46.8, 'quantity': 900},
#      {'price': 46.9, 'quantity': 450},
#      {'price': 47, 'quantity': 4200}],
#     'carryOfCost': {'price': {'bestBuy': 45,
#       'bestSell': 46.6,
#       'lastPrice': 46.6},
#      'carry': {'bestBuy': -42731.95473369865,
#       'bestSell': -42476.906958761305,
#       'lastPrice': -42476.906958761305}},
#     'tradeInfo': {'tradedVolume': 269277,
#      'value': 7627.94,
#      'vmap': 37.77,
#      'premiumTurnover': 3208658.2817175,
#      'openInterest': 17397,
#      'changeinOpenInterest': 4052,
#      'pchangeinOpenInterest': 30.36343199700262,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.64,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 16200,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE16200.00',
#     'openPrice': 4.1,
#     'highPrice': 6.7,
#     'lowPrice': 3.35,
#     'closePrice': 3.9,
#     'prevClose': 6.25,
#     'lastPrice': 3.7,
#     'change': -2.55,
#     'pChange': -40.8,
#     'numberOfContractsTraded': 240888,
#     'totalTurnover': 874.42},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 330750,
#     'totalSellQuantity': 144150,
#     'bid': [{'price': 3.85, 'quantity': 2250},
#      {'price': 3.7, 'quantity': 825},
#      {'price': 3.65, 'quantity': 150},
#      {'price': 3.6, 'quantity': 75},
#      {'price': 3.55, 'quantity': 8625}],
#     'ask': [{'price': 4, 'quantity': 450},
#      {'price': 4.2, 'quantity': 750},
#      {'price': 4.25, 'quantity': 75},
#      {'price': 4.3, 'quantity': 3000},
#      {'price': 4.45, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 3.85,
#       'bestSell': 4,
#       'lastPrice': 3.7},
#      'carry': {'bestBuy': -60679.656926434225,
#       'bestSell': -60400.642072846786,
#       'lastPrice': -60969.76132557569}},
#     'tradeInfo': {'tradedVolume': 240888,
#      'value': 874.42,
#      'vmap': 4.84,
#      'premiumTurnover': 2927663.62344,
#      'openInterest': 44293,
#      'changeinOpenInterest': 10146,
#      'pchangeinOpenInterest': 29.712712683398248,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.21,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15450,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15450.00',
#     'openPrice': 35.1,
#     'highPrice': 147.2,
#     'lowPrice': 21.35,
#     'closePrice': 33.1,
#     'prevClose': 45.6,
#     'lastPrice': 22.05,
#     'change': -23.55,
#     'pChange': -51.64473684210527,
#     'numberOfContractsTraded': 239977,
#     'totalTurnover': 11826.67},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 217950,
#     'totalSellQuantity': 97425,
#     'bid': [{'price': 21.3, 'quantity': 75},
#      {'price': 21.2, 'quantity': 75},
#      {'price': 21.15, 'quantity': 600},
#      {'price': 21, 'quantity': 450},
#      {'price': 20.1, 'quantity': 600}],
#     'ask': [{'price': 22.5, 'quantity': 75},
#      {'price': 22.95, 'quantity': 75},
#      {'price': 23.1, 'quantity': 75},
#      {'price': 23.25, 'quantity': 75},
#      {'price': 24, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 21.3,
#       'bestSell': 22.5,
#       'lastPrice': 22.05},
#      'carry': {'bestBuy': -3.80477406627084,
#       'bestSell': -47791.92915178625,
#       'lastPrice': -47939.40891520414}},
#     'tradeInfo': {'tradedVolume': 239977,
#      'value': 11826.67,
#      'vmap': 65.71,
#      'premiumTurnover': 2792560.1540025,
#      'openInterest': 6427,
#      'changeinOpenInterest': 2025,
#      'pchangeinOpenInterest': 46.001817355747384,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.08,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 16500,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE16500.00',
#     'openPrice': 3.25,
#     'highPrice': 3.8,
#     'lowPrice': 1.6,
#     'closePrice': 2.05,
#     'prevClose': 3.05,
#     'lastPrice': 1.95,
#     'change': -1.0999999999999999,
#     'pChange': -36.065573770491795,
#     'numberOfContractsTraded': 221719,
#     'totalTurnover': 452.31},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 677025,
#     'totalSellQuantity': 326700,
#     'bid': [{'price': 1.9, 'quantity': 2550},
#      {'price': 1.85, 'quantity': 11775},
#      {'price': 1.8, 'quantity': 23925},
#      {'price': 1.75, 'quantity': 17625},
#      {'price': 1.7, 'quantity': 7200}],
#     'ask': [{'price': 2, 'quantity': 4650},
#      {'price': 2.05, 'quantity': 5025},
#      {'price': 2.1, 'quantity': 2625},
#      {'price': 2.15, 'quantity': 3300},
#      {'price': 2.2, 'quantity': 8700}],
#     'carryOfCost': {'price': {'bestBuy': 1.9,
#       'bestSell': 2,
#       'lastPrice': 1.95},
#      'carry': {'bestBuy': -65835.0575399635,
#       'bestSell': -65460.61649093439,
#       'lastPrice': -65645.4364892197}},
#     'tradeInfo': {'tradedVolume': 221719,
#      'value': 452.31,
#      'vmap': 2.72,
#      'premiumTurnover': 2744224.9317600005,
#      'openInterest': 49450,
#      'changeinOpenInterest': 855,
#      'pchangeinOpenInterest': 1.759440271632884,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 17.67,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15950,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15950.00',
#     'openPrice': 37.4,
#     'highPrice': 37.4,
#     'lowPrice': 12.6,
#     'closePrice': 19,
#     'prevClose': 29.15,
#     'lastPrice': 21.65,
#     'change': -7.5,
#     'pChange': -25.728987993138936,
#     'numberOfContractsTraded': 206670,
#     'totalTurnover': 2991.55},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 292050,
#     'totalSellQuantity': 78150,
#     'bid': [{'price': 20.6, 'quantity': 75},
#      {'price': 20.55, 'quantity': 225},
#      {'price': 20, 'quantity': 750},
#      {'price': 19.75, 'quantity': 600},
#      {'price': 19, 'quantity': 1575}],
#     'ask': [{'price': 22, 'quantity': 1050},
#      {'price': 22.1, 'quantity': 225},
#      {'price': 22.2, 'quantity': 75},
#      {'price': 22.25, 'quantity': 75},
#      {'price': 22.5, 'quantity': 300}],
#     'carryOfCost': {'price': {'bestBuy': 20.6,
#       'bestSell': 22,
#       'lastPrice': 21.65},
#      'carry': {'bestBuy': -48435.966055714576,
#       'bestSell': -47955.980999506275,
#       'lastPrice': -48073.051091547946}},
#     'tradeInfo': {'tradedVolume': 206670,
#      'value': 2991.55,
#      'vmap': 19.3,
#      'premiumTurnover': 2475281.42325,
#      'openInterest': 13450,
#      'changeinOpenInterest': 4373,
#      'pchangeinOpenInterest': 48.1767103668613,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 12.19,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15100,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15100.00',
#     'openPrice': 11.65,
#     'highPrice': 44.95,
#     'lowPrice': 5.2,
#     'closePrice': 8.1,
#     'prevClose': 13.3,
#     'lastPrice': 6.4,
#     'change': -6.9,
#     'pChange': -51.8796992481203,
#     'numberOfContractsTraded': 185843,
#     'totalTurnover': 2334.65},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 217950,
#     'totalSellQuantity': 75750,
#     'bid': [{'price': 5.85, 'quantity': 75},
#      {'price': 5.2, 'quantity': 2100},
#      {'price': 5.1, 'quantity': 75},
#      {'price': 5, 'quantity': 825},
#      {'price': 4.95, 'quantity': 150}],
#     'ask': [{'price': 6.5, 'quantity': 1275},
#      {'price': 6.9, 'quantity': 300},
#      {'price': 7, 'quantity': 300},
#      {'price': 7.35, 'quantity': 150},
#      {'price': 7.45, 'quantity': 3000}],
#     'carryOfCost': {'price': {'bestBuy': 5.85,
#       'bestSell': 6.5,
#       'lastPrice': 6.4},
#      'carry': {'bestBuy': -57625.5667819425,
#       'bestSell': -56856.43501764037,
#       'lastPrice': -56969.61557935291}},
#     'tradeInfo': {'tradedVolume': 185843,
#      'value': 2334.65,
#      'vmap': 16.75,
#      'premiumTurnover': 2107006.6276875,
#      'openInterest': 18719,
#      'changeinOpenInterest': 4238,
#      'pchangeinOpenInterest': 29.265934673019817,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 18.07,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 15550,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE15550.00',
#     'openPrice': 235.55,
#     'highPrice': 256.5,
#     'lowPrice': 113.75,
#     'closePrice': 185.9,
#     'prevClose': 210.75,
#     'lastPrice': 213.5,
#     'change': 2.75,
#     'pChange': 1.3048635824436536,
#     'numberOfContractsTraded': 183953,
#     'totalTurnover': 19886.24},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 114075,
#     'totalSellQuantity': 23850,
#     'bid': [{'price': 210.5, 'quantity': 1050},
#      {'price': 210.45, 'quantity': 150},
#      {'price': 210.35, 'quantity': 75},
#      {'price': 210, 'quantity': 75},
#      {'price': 205, 'quantity': 75}],
#     'ask': [{'price': 217, 'quantity': 3675},
#      {'price': 217.2, 'quantity': 150},
#      {'price': 217.85, 'quantity': 225},
#      {'price': 218, 'quantity': 150},
#      {'price': 219, 'quantity': 225}],
#     'carryOfCost': {'price': {'bestBuy': 210.5,
#       'bestSell': 217,
#       'lastPrice': 213.5},
#      'carry': {'bestBuy': -31469.345641228203,
#       'bestSell': -31247.34022817663,
#       'lastPrice': -31366.042030540622}},
#     'tradeInfo': {'tradedVolume': 183953,
#      'value': 19886.24,
#      'vmap': 144.14,
#      'premiumTurnover': 2165238.101565,
#      'openInterest': 2282,
#      'changeinOpenInterest': 1184,
#      'pchangeinOpenInterest': 107.83242258652095,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 14.7,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15350,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15350.00',
#     'openPrice': 20.55,
#     'highPrice': 106.6,
#     'lowPrice': 12.65,
#     'closePrice': 19.95,
#     'prevClose': 30.3,
#     'lastPrice': 12.65,
#     'change': -17.65,
#     'pChange': -58.25082508250824,
#     'numberOfContractsTraded': 182034,
#     'totalTurnover': 5959.34},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 302625,
#     'totalSellQuantity': 45375,
#     'bid': [{'price': 12.65, 'quantity': 12075},
#      {'price': 12, 'quantity': 1275},
#      {'price': 11.5, 'quantity': 375},
#      {'price': 11.05, 'quantity': 900},
#      {'price': 11, 'quantity': 75}],
#     'ask': [{'price': 13.4, 'quantity': 300},
#      {'price': 13.95, 'quantity': 150},
#      {'price': 14, 'quantity': 75},
#      {'price': 14.35, 'quantity': 900},
#      {'price': 14.5, 'quantity': 1500}],
#     'carryOfCost': {'price': {'bestBuy': 12.65,
#       'bestSell': 13.4,
#       'lastPrice': 12.65},
#      'carry': {'bestBuy': -51995.693238255226,
#       'bestSell': -51575.231548236865,
#       'lastPrice': -51995.693238255226}},
#     'tradeInfo': {'tradedVolume': 182034,
#      'value': 5959.34,
#      'vmap': 43.65,
#      'premiumTurnover': 2101625.763075,
#      'openInterest': 8049,
#      'changeinOpenInterest': 3783,
#      'pchangeinOpenInterest': 88.67791842475387,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 13.9,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Call',
#     'strikePrice': 16300,
#     'identifier': 'OPTIDXNIFTY24-06-2021CE16300.00',
#     'openPrice': 4.6,
#     'highPrice': 7.45,
#     'lowPrice': 2.1,
#     'closePrice': 2.5,
#     'prevClose': 4.25,
#     'lastPrice': 2.3,
#     'change': -1.9500000000000002,
#     'pChange': -45.88235294117647,
#     'numberOfContractsTraded': 181370,
#     'totalTurnover': 478.82},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 153150,
#     'totalSellQuantity': 140775,
#     'bid': [{'price': 2.3, 'quantity': 900},
#      {'price': 2.25, 'quantity': 975},
#      {'price': 2.2, 'quantity': 3225},
#      {'price': 2.15, 'quantity': 75},
#      {'price': 2.05, 'quantity': 75}],
#     'ask': [{'price': 2.5, 'quantity': 8700},
#      {'price': 2.55, 'quantity': 300},
#      {'price': 2.75, 'quantity': 75},
#      {'price': 2.9, 'quantity': 3075},
#      {'price': 2.95, 'quantity': 1050}],
#     'carryOfCost': {'price': {'bestBuy': 2.3,
#       'bestSell': 2.5,
#       'lastPrice': 2.3},
#      'carry': {'bestBuy': -64440.35431159573,
#       'bestSell': -63831.66856634065,
#       'lastPrice': -64440.35431159573}},
#     'tradeInfo': {'tradedVolume': 181370,
#      'value': 478.82,
#      'vmap': 3.52,
#      'premiumTurnover': 2217727.0668,
#      'openInterest': 25027,
#      'changeinOpenInterest': 350,
#      'pchangeinOpenInterest': 1.418324755845524,
#      'marketLot': 75},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 1.39,
#      'annualisedVolatility': 26.54,
#      'impliedVolatility': 14.21,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '24-Jun-2021',
#     'optionType': 'Put',
#     'strikePrice': 15800,
#     'identifier': 'OPTIDXNIFTY24-06-2021PE15800.00',
#     'openPrice': 147.05,
#     'highPrice': 373.25,
#     'lowPrice': 132.15,
#     'closePrice': 162.5,
#     'prevClose': 179.05,
#     'lastPrice': 134,
#     'change': -45.05000000000001,
#     'pChange': -25.160569673275624,
#     'numberOfContractsTraded': 172328,
#     'totalTurnover': 27268.32},
#    'underlyingValue': 15683.35,
#    'volumeFreezeQuantity': 5001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 152475,
#     'totalSellQuantity': 61500,
#     'bid': [{'price': 134, 'quantity': 75},
#      {'price': 133, 'quantity': 3825},
#      {'price': 132.6, 'quantity': 75},
#      {'price': 132.2, 'quantity': 150},
#      {'price': 132.1, 'quantity': 975}],
#     'ask': [{'price': 136.95, 'quantity': 375},
#      {'price': 137, 'quantity': 750},
#      {'price': 138.1, 'quantity': 75},
#      {'price': 138.35, 'quantity': 75},
#      {'price': 138.4, 'quantity': 75}],
#     'carryOfCost': {'price': {'bestBuy': 134,
#       'bestSell': 136.95,
#       'lastPrice': 134},
#      'carry': {'bestBuy': -34766.36036938033,
#       'bestSell': -34607.39487034565,
#       'lastPrice': -34766.36036938033}},
#     'tradeInfo': {'tradedVolume': 172328,
# ...
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '24-Jun-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '01-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '08-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '15-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '22-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   '29-Jul-2021',
#   ...]}
