# %%
import nsepython
ticker = 'MARUTI'

# %%
nsepython.option_chain(ticker)
# Out:
# {'records': {'expiryDates': ['29-Jul-2021', '26-Aug-2021', '30-Sep-2021'],
#   'data': [{'strikePrice': 4800,
#     'expiryDate': '29-Jul-2021',
#     'PE': {'strikePrice': 4800,
#      'expiryDate': '29-Jul-2021',
#      'underlying': 'MARUTI',
#      'identifier': 'OPTSTKMARUTI29-07-2021PE4800.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 3,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3700,
#      'totalSellQuantity': 100,
#      'bidQty': 100,
#      'bidprice': 0.35,
#      'askQty': 100,
#      'askPrice': 3.05,
#      'underlyingValue': 7423},
#     'CE': {'strikePrice': 4800,
#      'expiryDate': '29-Jul-2021',
#      'underlying': 'MARUTI',
#      'identifier': 'OPTSTKMARUTI29-07-2021CE4800.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
# ...
