# %%
from nsepy import get_history
from nsepy.derivatives import get_expiry_date
from datetime import date

# %%
get_expiry_date(year=2021, month=3)
# Out:
# {datetime.date(2021, 3, 4),
#  datetime.date(2021, 3, 10),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 25)}

# %%
get_history(symbol="SBIN",
                        start=date(2021,1,1),
                        end=date(2021,1,10),
                        option_type='CE',
                        strike_price=280,
                        expiry_date=date(2021,3,25))
# Out:
#            Symbol      Expiry Option Type  Strike Price  Open  High  Low  \
# Date
# 2021-01-01   SBIN  2021-03-25          CE         280.0   0.0   0.0  0.0
# 2021-01-04   SBIN  2021-03-25          CE         280.0   0.0   0.0  0.0
# 2021-01-05   SBIN  2021-03-25          CE         280.0   0.0   0.0  0.0
# 2021-01-06   SBIN  2021-03-25          CE         280.0   0.0   0.0  0.0
# 2021-01-07   SBIN  2021-03-25          CE         280.0   0.0   0.0  0.0
# 2021-01-08   SBIN  2021-03-25          CE         280.0   0.0   0.0  0.0
#
#             Close  Last  Settle Price  Number of Contracts  Turnover  \
# Date
# 2021-01-01  25.95   0.0          23.6                    0       0.0
# 2021-01-04  25.95   0.0          24.0                    0       0.0
# 2021-01-05  25.95   0.0          24.2                    0       0.0
# 2021-01-06  25.95   0.0          25.9                    0       0.0
# 2021-01-07  25.95   0.0          27.3                    0       0.0
# 2021-01-08  25.95   0.0          26.1                    0       0.0
#
#             Premium Turnover  Open Interest  Change in OI  Underlying
# Date
# 2021-01-01               0.0              0             0      279.40
# 2021-01-04               0.0              0             0      281.05
# 2021-01-05               0.0              0             0         NaN
# 2021-01-06               0.0              0             0         NaN
# 2021-01-07               0.0              0             0      287.70
# 2021-01-08               0.0              0             0         NaN

# %%
from nsetools import Nse
nse = Nse()
nse.get_fno_lot_sizes()
# Out:
# {'NIFTY': 75,
#  'FINNIFTY': 40,
#  'BANKNIFTY': 25,
#  'AARTIIND': 425,
#  'ADANIENT': 2000,
#  'ADANIPORTS': 2500,
#  'AMARAJABAT': 1000,
#  'APOLLOTYRE': 5000,
#  'ACC': 500,
#  'ASHOKLEY': 9000,
#  'ASIANPAINT': 300,
#  'AUROPHARMA': 650,
#  'AMBUJACEM': 3000,
#  'BAJAJ-AUTO': 250,
#  'BANKBARODA': 11700,
#  'BALKRISIND': 400,
#  'BATAINDIA': 550,
#  'BERGEPAINT': 1100,
#  'BEL': 7600,
#  'BHARATFORG': 1500,
#  'BHARTIARTL': 1851,
#  'BIOCON': 2300,
#  'BHEL': 21000,
#  'BOSCHLTD': 50,
#  'BRITANNIA': 200,
#  'CADILAHC': 2200,
#  'CANBK': 5400,
#  'CHOLAFIN': 2500,
#  'CIPLA': 1300,
#  'COLPAL': 700,
#  'COALINDIA': 4200,
#  'CONCOR': 1563,
#  'CUMMINSIND': 1200,
#  'DLF': 3300,
#  'DABUR': 1250,
#  'DIVISLAB': 200,
#  'DRREDDY': 125,
#  'ESCORTS': 550,
#  'FEDERALBNK': 10000,
#  'GLENMARK': 1150,
#  'GODREJPROP': 650,
#  'HAVELLS': 1000,
#  'GMRINFRA': 22500,
#  'HDFCAMC': 200,
#  'HDFCBANK': 550,
#  'HINDUNILVR': 300,
#  'ICICIBANK': 1375,
#  'IGL': 1375,
#  'INDUSTOWER': 2800,
#  'IOC': 6500,
#  'HCLTECH': 700,
#  'HDFC': 300,
#  'ITC': 3200,
#  'JINDALSTEL': 5000,
#  'JSWSTEEL': 2700,
#  'HINDALCO': 4300,
#  'L&TFH': 8924,
#  'IBULHSGFIN': 3100,
#  'ICICIGI': 425,
#  'LALPATHLAB': 250,
#  'ICICIPRULI': 1500,
#  'LICHSGFIN': 2000,
#  'LT': 575,
#  'LUPIN': 850,
#  'INDIGO': 500,
#  'M&M': 1400,
#  'M&MFIN': 4000,
#  'MANAPPURAM': 6000,
#  'MARUTI': 100,
#  'INFY': 600,
#  'MFSL': 1300,
#  'NATIONALUM': 17000,
#  'NESTLEIND': 50,
#  'NMDC': 6700,
#  'PAGEIND': 30,
#  'JUBLFOOD': 250,
#  'PEL': 550,
#  'PIDILITIND': 500,
#  'PNB': 16000,
#  'MINDTREE': 800,
#  'MOTHERSUMI': 7000,
#  'PVR': 407,
#  'SAIL': 19000,
#  'SBIN': 3000,
#  'SIEMENS': 550,
#  'MUTHOOTFIN': 750,
#  'SRF': 125,
#  'NAUKRI': 250,
#  'SRTRANSFIN': 800,
#  'SUNPHARMA': 1400,
#  'TATACONSUM': 1350,
#  'TATAPOWER': 13500,
#  'TCS': 300,
#  'TECHM': 1200,
#  'NTPC': 5700,
#  'TORNTPOWER': 3000,
#  'VEDL': 6200,
#  'ONGC': 7700,
#  'WIPRO': 3200,
#  'PETRONET': 3000,
#  'APOLLOHOSP': 500,
#  'POWERGRID': 4000,
#  'RECLTD': 6000,
#  'RELIANCE': 250,
#  'BAJFINANCE': 250,
#  'TATASTEEL': 1700,
#  'BPCL': 1800,
#  'TITAN': 750,
#  'TORNTPHARM': 250,
#  'TVSMOTOR': 1400,
#  'COFORGE': 375,
#  'EICHERMOT': 350,
#  'EXIDEIND': 3600,
#  'GAIL': 6100,
#  'GODREJCP': 1000,
#  'GRASIM': 950,
#  'HDFCLIFE': 1100,
#  'HEROMOTOCO': 300,
#  'AXISBANK': 1200,
#  'HINDPETRO': 2700,
#  'BAJAJFINSV': 125,
#  'IDEA': 70000,
#  'IDFCFIRSTB': 19000,
#  'KOTAKBANK': 400,
#  'MARICO': 2000,
#  'MGL': 600,
#  'MRF': 10,
#  'PFC': 6200,
#  'RBLBANK': 2900,
#  'INDUSINDBK': 900,
#  'SBILIFE': 750,
#  'SUNTV': 1500,
#  'TATACHEM': 2000,
#  'TATAMOTORS': 5700,
#  'ULTRACEMCO': 200,
#  'MCDOWELL-N': 1250,
#  'VOLTAS': 1000,
#  'UPL': 1300,
#  'ZEEL': 3000,
#  'RAMCOCEM': 850,
#  'SHREECEM': 50,
#  'UBL': 700,
#  'BANDHANBNK': 1800,
#  'ALKEM': 200,
#  'APLLTD': 550,
#  'AUBANK': 500,
#  'CUB': 3100,
#  'DEEPAKNTR': 500,
#  'GRANULES': 1550,
#  'GUJGASLTD': 1250,
#  'IRCTC': 325,
#  'LTI': 150,
#  'LTTS': 200,
#  'MPHASIS': 325,
#  'NAM-INDIA': 1600,
#  'NAVINFLUOR': 225,
#  'PFIZER': 125,
#  'PIIND': 250,
#  'TRENT': 725}

# %%
from yahoo_fin.stock_info import *

# %%
import nsepython

# %%
nsepython.fnolist()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 39299
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 24118
# ['NIFTY',
#  'NIFTYIT',
#  'BANKNIFTY',
#  'ADANIENT',
#  'GODREJPROP',
#  'ACC',
#  'ADANIPORTS',
#  'PAGEIND',
#  'AMBUJACEM',
#  'APLLTD',
#  'TATACONSUM',
#  'GODREJCP',
#  'CHOLAFIN',
#  'IDEA',
#  'JINDALSTEL',
#  'NAM-INDIA',
#  'TECHM',
#  'TCS',
#  'BRITANNIA',
#  'INDIGO',
#  'AARTIIND',
#  'VOLTAS',
#  'DLF',
#  'SUNPHARMA',
#  'UBL',
#  'PETRONET',
#  'AUROPHARMA',
#  'RAMCOCEM',
#  'GMRINFRA',
#  'INFY',
#  'HINDALCO',
#  'ICICIPRULI',
#  'AUBANK',
#  'BANDHANBNK',
#  'DRREDDY',
#  'LALPATHLAB',
#  'HCLTECH',
#  'HINDUNILVR',
#  'BIOCON',
#  'DABUR',
#  'NAUKRI',
#  'TATASTEEL',
#  'NTPC',
#  'ESCORTS',
#  'MARICO',
#  'CIPLA',
#  'TORNTPHARM',
#  'TATACHEM',
#  'ITC',
#  'EXIDEIND',
#  'IGL',
#  'BPCL',
#  'CADILAHC',
#  'MGL',
#  'WIPRO',
#  'LUPIN',
#  'JSWSTEEL',
#  'DEEPAKNTR',
#  'MCDOWELL-N',
#  'SUNTV',
#  'DIVISLAB',
#  'ULTRACEMCO',
#  'BERGEPAINT',
#  'HINDPETRO',
#  'PFIZER',
#  'NESTLEIND',
#  'AMARAJABAT',
#  'ASIANPAINT',
#  'EICHERMOT',
#  'PIIND',
#  'TRENT',
#  'SRTRANSFIN',
#  'JUBLFOOD',
#  'MINDTREE',
#  'TATAPOWER',
#  'MPHASIS',
#  'PIDILITIND',
#  'GLENMARK',
#  'IOC',
#  'HDFCAMC',
#  'BHEL',
#  'ALKEM',
#  'LTI',
#  'GRASIM',
#  'PEL',
#  'BAJAJ-AUTO',
#  'MUTHOOTFIN',
#  'NAVINFLUOR',
#  'VEDL',
#  'APOLLOTYRE',
#  'LTTS',
#  'HDFC',
#  'TORNTPOWER',
#  'M&M',
#  'BEL',
#  'UPL',
#  'BALKRISIND',
#  'COLPAL',
#  'SHREECEM',
#  'MARUTI',
#  'ICICIGI',
#  'SIEMENS',
#  'CUB',
#  'TITAN',
#  'SAIL',
#  'CONCOR',
#  'BATAINDIA',
#  'LICHSGFIN',
#  'BAJAJFINSV',
#  'KOTAKBANK',
#  'COALINDIA',
#  'BHARATFORG',
#  'CANBK',
#  'SRF',
#  'BHARTIARTL',
#  'HEROMOTOCO',
#  'TVSMOTOR',
#  'LT',
#  'GRANULES',
#  'CUMMINSIND',
#  'GAIL',
#  'FEDERALBNK',
#  'ZEEL',
#  'ONGC',
#  'IBULHSGFIN',
#  'APOLLOHOSP',
#  'SBIN',
#  'IRCTC',
#  'RELIANCE',
#  'SBILIFE',
#  'MRF',
#  'BOSCHLTD',
#  'HAVELLS',
#  'HDFCLIFE',
#  'BAJFINANCE',
#  'AXISBANK',
#  'MANAPPURAM',
#  'COFORGE',
#  'RBLBANK',
#  'GUJGASLTD',
#  'IDFCFIRSTB',
#  'PNB',
#  'HDFCBANK',
#  'PFC',
#  'BANKBARODA',
#  'MFSL',
#  'TATAMOTORS',
#  'M&MFIN',
#  'MOTHERSUMI',
#  'ASHOKLEY',
#  'ICICIBANK',
#  'L&TFH',
#  'INDUSTOWER',
#  'NATIONALUM',
#  'RECLTD',
#  'PVR',
#  'POWERGRID',
#  'NMDC',
#  'INDUSINDBK']

# %%
y = nsepython.nse_fno("NATIONALUM")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=NATIONALUM HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 39288
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=NATIONALUM HTTP/1.1" 200 18744

# %%
y
# Out:
# {'info': {'symbol': 'NATIONALUM',
#   'companyName': 'National Aluminium Company Limited',
#   'industry': 'ALUMINIUM',
#   'activeSeries': ['EQ'],
#   'debtSeries': [],
#   'tempSuspendedSeries': [],
#   'isFNOSec': True,
#   'isCASec': False,
#   'isSLBSec': False,
#   'isDebtSec': False,
#   'isSuspended': False,
#   'isETFSec': False,
#   'isDelisted': False,
#   'isin': 'INE139A01034'},
#  'underlyingValue': 54.45,
#  'vfq': 850001,
#  'fut_timestamp': '22-Mar-2021 15:26:39',
#  'opt_timestamp': '22-Mar-2021 15:29:23',
#  'stocks': [{'metadata': {'instrumentType': 'Stock Futures',
#     'expiryDate': '25-Mar-2021',
#     'optionType': '-',
#     'strikePrice': 0,
#     'identifier': 'FUTSTKNATIONALUM25-03-2021XX0.00',
#     'openPrice': 53.95,
#     'highPrice': 55.25,
#     'lowPrice': 53.95,
#     'closePrice': 54.5,
#     'prevClose': 54.05,
#     'lastPrice': 54.45,
#     'change': 0.4000000000000057,
#     'pChange': 0.7400555041628227,
#     'numberOfContractsTraded': 1642,
#     'totalTurnover': 15277.33},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 0,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2737000,
#     'totalSellQuantity': 4930000,
#     'bid': [{'price': 54.4, 'quantity': 17000},
#      {'price': 54.35, 'quantity': 85000},
#      {'price': 54.3, 'quantity': 170000},
#      {'price': 54.25, 'quantity': 85000},
#      {'price': 54.2, 'quantity': 136000}],
#     'ask': [{'price': 54.5, 'quantity': 119000},
#      {'price': 54.55, 'quantity': 136000},
#      {'price': 54.6, 'quantity': 204000},
#      {'price': 54.65, 'quantity': 204000},
#      {'price': 54.7, 'quantity': 204000}],
#     'carryOfCost': {'price': {'bestBuy': 54.4,
#       'bestSell': 54.5,
#       'lastPrice': 54.45},
#      'carry': {'bestBuy': -11.177462124383062,
#       'bestSell': 11.167202864452344,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 1642,
#      'value': 15277.33,
#      'vmap': 54.73,
#      'premiumTurnover': 15277.3322,
#      'openInterest': 3002,
#      'changeinOpenInterest': -471,
#      'pchangeinOpenInterest': -13.561762165274978,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 54.5,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Futures',
#     'expiryDate': '29-Apr-2021',
#     'optionType': '-',
#     'strikePrice': 0,
#     'identifier': 'FUTSTKNATIONALUM29-04-2021XX0.00',
#     'openPrice': 54.35,
#     'highPrice': 55.6,
#     'lowPrice': 54.35,
#     'closePrice': 54.9,
#     'prevClose': 54.35,
#     'lastPrice': 54.8,
#     'change': 0.44999999999999574,
#     'pChange': 0.8279668813247392,
#     'numberOfContractsTraded': 1154,
#     'totalTurnover': 10793.82},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 0,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2788000,
#     'totalSellQuantity': 3825000,
#     'bid': [{'price': 54.75, 'quantity': 51000},
#      {'price': 54.7, 'quantity': 68000},
#      {'price': 54.65, 'quantity': 102000},
#      {'price': 54.6, 'quantity': 102000},
#      {'price': 54.55, 'quantity': 85000}],
#     'ask': [{'price': 54.85, 'quantity': 85000},
#      {'price': 54.9, 'quantity': 68000},
#      {'price': 54.95, 'quantity': 51000},
#      {'price': 55, 'quantity': 272000},
#      {'price': 55.05, 'quantity': 34000}],
#     'carryOfCost': {'price': {'bestBuy': 54.75,
#       'bestSell': 54.85,
#       'lastPrice': 54.8},
#      'carry': {'bestBuy': 5.2776303972075915,
#       'bestSell': 7.030416131390634,
#       'lastPrice': 6.154423078618665}},
#     'tradeInfo': {'tradedVolume': 1154,
#      'value': 10793.82,
#      'vmap': 55.02,
#      'premiumTurnover': 10793.8236,
#      'openInterest': 1151,
#      'changeinOpenInterest': 320,
#      'pchangeinOpenInterest': 38.50782190132371,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 54.9,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 55,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE55.00',
#     'openPrice': 0.75,
#     'highPrice': 1,
#     'lowPrice': 0.55,
#     'closePrice': 0.65,
#     'prevClose': 0.75,
#     'lastPrice': 0.7,
#     'change': -0.050000000000000044,
#     'pChange': -6.666666666666672,
#     'numberOfContractsTraded': 355,
#     'totalTurnover': 45.26},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 6205000,
#     'totalSellQuantity': 1207000,
#     'bid': [{'price': 0.6, 'quantity': 68000},
#      {'price': 0.55, 'quantity': 85000},
#      {'price': 0.5, 'quantity': 119000},
#      {'price': 0.45, 'quantity': 119000},
#      {'price': 0.4, 'quantity': 136000}],
#     'ask': [{'price': 0.65, 'quantity': 51000},
#      {'price': 0.7, 'quantity': 34000},
#      {'price': 0.75, 'quantity': 17000},
#      {'price': 0.9, 'quantity': 17000},
#      {'price': 0.95, 'quantity': 34000}],
#     'carryOfCost': {'price': {'bestBuy': 0.6,
#       'bestSell': 0.65,
#       'lastPrice': 0.7},
#      'carry': {'bestBuy': -54848.653089930354,
#       'bestSell': -53874.80014656899,
#       'lastPrice': -52973.153152032035}},
#     'tradeInfo': {'tradedVolume': 355,
#      'value': 45.26,
#      'vmap': 0.75,
#      'premiumTurnover': 3364.5125,
#      'openInterest': 161,
#      'changeinOpenInterest': -6,
#      'pchangeinOpenInterest': -3.592814371257485,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 43.97,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 56,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE56.00',
#     'openPrice': 0.5,
#     'highPrice': 0.55,
#     'lowPrice': 0.3,
#     'closePrice': 0.35,
#     'prevClose': 0.5,
#     'lastPrice': 0.4,
#     'change': -0.09999999999999998,
#     'pChange': -19.999999999999996,
#     'numberOfContractsTraded': 272,
#     'totalTurnover': 20.81},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 3247000,
#     'totalSellQuantity': 1564000,
#     'bid': [{'price': 0.35, 'quantity': 85000},
#      {'price': 0.3, 'quantity': 221000},
#      {'price': 0.25, 'quantity': 85000},
#      {'price': 0.2, 'quantity': 272000},
#      {'price': 0.15, 'quantity': 272000}],
#     'ask': [{'price': 0.4, 'quantity': 306000},
#      {'price': 0.45, 'quantity': 85000},
#      {'price': 0.55, 'quantity': 51000},
#      {'price': 0.6, 'quantity': 85000},
#      {'price': 0.7, 'quantity': 136000}],
#     'carryOfCost': {'price': {'bestBuy': 0.35,
#       'bestSell': 0.4,
#       'lastPrice': 0.4},
#      'carry': {'bestBuy': -61406.443848844705,
#       'bestSell': -59781.811905246344,
#       'lastPrice': -59781.811905246344}},
#     'tradeInfo': {'tradedVolume': 272,
#      'value': 20.81,
#      'vmap': 0.45,
#      'premiumTurnover': 2610.248,
#      'openInterest': 111,
#      'changeinOpenInterest': 35,
#      'pchangeinOpenInterest': 46.05263157894737,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 47.27,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 60,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE60.00',
#     'openPrice': 0.15,
#     'highPrice': 0.2,
#     'lowPrice': 0.1,
#     'closePrice': 0.15,
#     'prevClose': 0.2,
#     'lastPrice': 0.15,
#     'change': -0.05000000000000002,
#     'pChange': -25.000000000000007,
#     'numberOfContractsTraded': 179,
#     'totalTurnover': 4.56},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 6222000,
#     'totalSellQuantity': 3842000,
#     'bid': [{'price': 0.1, 'quantity': 2329000},
#      {'price': 0.05, 'quantity': 3893000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.15, 'quantity': 731000},
#      {'price': 0.2, 'quantity': 595000},
#      {'price': 0.25, 'quantity': 102000},
#      {'price': 0.3, 'quantity': 85000},
#      {'price': 0.35, 'quantity': 34000}],
#     'carryOfCost': {'price': {'bestBuy': 0.1,
#       'bestSell': 0.15,
#       'lastPrice': 0.15},
#      'carry': {'bestBuy': -76648.39329887168,
#       'bestSell': -71715.23448355569,
#       'lastPrice': -71715.23448355569}},
#     'tradeInfo': {'tradedVolume': 179,
#      'value': 4.56,
#      'vmap': 0.15,
#      'premiumTurnover': 1830.3645,
#      'openInterest': 774,
#      'changeinOpenInterest': 4,
#      'pchangeinOpenInterest': 0.5194805194805194,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 70.7,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 50,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE50.00',
#     'openPrice': 0.15,
#     'highPrice': 0.15,
#     'lowPrice': 0.05,
#     'closePrice': 0.1,
#     'prevClose': 0.2,
#     'lastPrice': 0.1,
#     'change': -0.1,
#     'pChange': -50,
#     'numberOfContractsTraded': 164,
#     'totalTurnover': 2.79},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2703000,
#     'totalSellQuantity': 2703000,
#     'bid': [{'price': 0.1, 'quantity': 51000},
#      {'price': 0.05, 'quantity': 2652000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.15, 'quantity': 493000},
#      {'price': 0.2, 'quantity': 884000},
#      {'price': 0.25, 'quantity': 17000},
#      {'price': 0.3, 'quantity': 85000},
#      {'price': 0.4, 'quantity': 136000}],
#     'carryOfCost': {'price': {'bestBuy': 0.1,
#       'bestSell': 0.15,
#       'lastPrice': 0.1},
#      'carry': {'bestBuy': -76648.39329887168,
#       'bestSell': -71715.23448355569,
#       'lastPrice': -76648.39329887168}},
#     'tradeInfo': {'tradedVolume': 164,
#      'value': 2.79,
#      'vmap': 0.1,
#      'premiumTurnover': 1396.788,
#      'openInterest': 211,
#      'changeinOpenInterest': -11,
#      'pchangeinOpenInterest': -4.954954954954955,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 71.02,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 54,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE54.00',
#     'openPrice': 0.7,
#     'highPrice': 0.8,
#     'lowPrice': 0.4,
#     'closePrice': 0.65,
#     'prevClose': 1,
#     'lastPrice': 0.65,
#     'change': -0.35,
#     'pChange': -35,
#     'numberOfContractsTraded': 125,
#     'totalTurnover': 12.11},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 3468000,
#     'totalSellQuantity': 1037000,
#     'bid': [{'price': 0.55, 'quantity': 51000},
#      {'price': 0.5, 'quantity': 102000},
#      {'price': 0.45, 'quantity': 17000},
#      {'price': 0.4, 'quantity': 102000},
#      {'price': 0.35, 'quantity': 85000}],
#     'ask': [{'price': 0.65, 'quantity': 68000},
#      {'price': 0.7, 'quantity': 17000},
#      {'price': 0.8, 'quantity': 17000},
#      {'price': 0.85, 'quantity': 17000},
#      {'price': 0.9, 'quantity': 85000}],
#     'carryOfCost': {'price': {'bestBuy': 0.55,
#       'bestSell': 0.65,
#       'lastPrice': 0.65},
#      'carry': {'bestBuy': -55907.29150997084,
#       'bestSell': -53874.80014656899,
#       'lastPrice': -53874.80014656899}},
#     'tradeInfo': {'tradedVolume': 125,
#      'value': 12.11,
#      'vmap': 0.57,
#      'premiumTurnover': 1159.6125,
#      'openInterest': 78,
#      'changeinOpenInterest': 2,
#      'pchangeinOpenInterest': 2.6315789473684212,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 39.9,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 58,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE58.00',
#     'openPrice': 0.3,
#     'highPrice': 0.3,
#     'lowPrice': 0.15,
#     'closePrice': 0.2,
#     'prevClose': 0.3,
#     'lastPrice': 0.15,
#     'change': -0.15,
#     'pChange': -50,
#     'numberOfContractsTraded': 119,
#     'totalTurnover': 4.05},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2108000,
#     'totalSellQuantity': 1377000,
#     'bid': [{'price': 0.2, 'quantity': 34000},
#      {'price': 0.15, 'quantity': 153000},
#      {'price': 0.1, 'quantity': 1003000},
#      {'price': 0.05, 'quantity': 918000},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.25, 'quantity': 170000},
#      {'price': 0.3, 'quantity': 17000},
#      {'price': 0.35, 'quantity': 17000},
#      {'price': 0.4, 'quantity': 34000},
#      {'price': 0.45, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.2,
#       'bestSell': 0.25,
#       'lastPrice': 0.15},
#      'carry': {'bestBuy': -68215.102602059,
#       'bestSell': -65500.18939440279,
#       'lastPrice': -71715.23448355569}},
#     'tradeInfo': {'tradedVolume': 119,
#      'value': 4.05,
#      'vmap': 0.2,
#      'premiumTurnover': 1177.386,
#      'openInterest': 155,
#      'changeinOpenInterest': 8,
#      'pchangeinOpenInterest': 5.442176870748299,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 62.08,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 53,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE53.00',
#     'openPrice': 0.5,
#     'highPrice': 0.5,
#     'lowPrice': 0.25,
#     'closePrice': 0.35,
#     'prevClose': 0.75,
#     'lastPrice': 0.35,
#     'change': -0.4,
#     'pChange': -53.333333333333336,
#     'numberOfContractsTraded': 116,
#     'totalTurnover': 6.51},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2652000,
#     'totalSellQuantity': 680000,
#     'bid': [{'price': 0.3, 'quantity': 85000},
#      {'price': 0.25, 'quantity': 238000},
#      {'price': 0.2, 'quantity': 136000},
#      {'price': 0.15, 'quantity': 272000},
#      {'price': 0.1, 'quantity': 612000}],
#     'ask': [{'price': 0.35, 'quantity': 51000},
#      {'price': 0.4, 'quantity': 85000},
#      {'price': 0.45, 'quantity': 17000},
#      {'price': 2, 'quantity': 17000},
#      {'price': 2.05, 'quantity': 391000}],
#     'carryOfCost': {'price': {'bestBuy': 0.3,
#       'bestSell': 0.35,
#       'lastPrice': 0.35},
#      'carry': {'bestBuy': -63281.943786743024,
#       'bestSell': -61406.443848844705,
#       'lastPrice': -61406.443848844705}},
#     'tradeInfo': {'tradedVolume': 116,
#      'value': 6.51,
#      'vmap': 0.33,
#      'premiumTurnover': 1051.6676,
#      'openInterest': 77,
#      'changeinOpenInterest': -10,
#      'pchangeinOpenInterest': -11.494252873563218,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 41.95,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 55,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE55.00',
#     'openPrice': 1.3,
#     'highPrice': 1.45,
#     'lowPrice': 0.75,
#     'closePrice': 1.1,
#     'prevClose': 1.5,
#     'lastPrice': 1.05,
#     'change': -0.44999999999999996,
#     'pChange': -30,
#     'numberOfContractsTraded': 108,
#     'totalTurnover': 17.63},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2210000,
#     'totalSellQuantity': 1003000,
#     'bid': [{'price': 1.1, 'quantity': 51000},
#      {'price': 1.05, 'quantity': 34000},
#      {'price': 0.8, 'quantity': 17000},
#      {'price': 0.75, 'quantity': 170000},
#      {'price': 0.7, 'quantity': 34000}],
#     'ask': [{'price': 1.25, 'quantity': 51000},
#      {'price': 1.35, 'quantity': 34000},
#      {'price': 1.4, 'quantity': 34000},
#      {'price': 1.65, 'quantity': 17000},
#      {'price': 2.9, 'quantity': 391000}],
#     'carryOfCost': {'price': {'bestBuy': 1.1,
#       'bestSell': 1.25,
#       'lastPrice': 1.05},
#      'carry': {'bestBuy': -47474.00081315817,
#       'bestSell': -45918.69479312124,
#       'lastPrice': -48039.99433671604}},
#     'tradeInfo': {'tradedVolume': 108,
#      'value': 17.63,
#      'vmap': 0.96,
#      'premiumTurnover': 1027.4256,
#      'openInterest': 123,
#      'changeinOpenInterest': -20,
#      'pchangeinOpenInterest': -13.986013986013987,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 35.76,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 57,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE57.00',
#     'openPrice': 0.4,
#     'highPrice': 0.4,
#     'lowPrice': 0.2,
#     'closePrice': 0.3,
#     'prevClose': 0.4,
#     'lastPrice': 0.3,
#     'change': -0.10000000000000003,
#     'pChange': -25.000000000000007,
#     'numberOfContractsTraded': 106,
#     'totalTurnover': 4.87},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 2703000,
#     'totalSellQuantity': 1343000,
#     'bid': [{'price': 0.25, 'quantity': 85000},
#      {'price': 0.2, 'quantity': 255000},
#      {'price': 0.15, 'quantity': 357000},
#      {'price': 0.1, 'quantity': 816000},
#      {'price': 0.05, 'quantity': 1190000}],
#     'ask': [{'price': 0.3, 'quantity': 136000},
#      {'price': 0.35, 'quantity': 119000},
#      {'price': 0.4, 'quantity': 102000},
#      {'price': 0.45, 'quantity': 17000},
#      {'price': 0.5, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.25,
#       'bestSell': 0.3,
#       'lastPrice': 0.3},
#      'carry': {'bestBuy': -65500.18939440279,
#       'bestSell': -63281.943786743024,
#       'lastPrice': -63281.943786743024}},
#     'tradeInfo': {'tradedVolume': 106,
#      'value': 4.87,
#      'vmap': 0.27,
#      'premiumTurnover': 1032.0054,
#      'openInterest': 97,
#      'changeinOpenInterest': 3,
#      'pchangeinOpenInterest': 3.1914893617021276,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 58.05,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 60,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE60.00',
#     'openPrice': 1.15,
#     'highPrice': 1.75,
#     'lowPrice': 1.15,
#     'closePrice': 1.55,
#     'prevClose': 1.5,
#     'lastPrice': 1.6,
#     'change': 0.10000000000000009,
#     'pChange': 6.666666666666672,
#     'numberOfContractsTraded': 80,
#     'totalTurnover': 21.62},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 1547000,
#     'totalSellQuantity': 1088000,
#     'bid': [{'price': 1.5, 'quantity': 34000},
#      {'price': 1.45, 'quantity': 51000},
#      {'price': 1.4, 'quantity': 34000},
#      {'price': 1.35, 'quantity': 17000},
#      {'price': 1.25, 'quantity': 17000}],
#     'ask': [{'price': 1.6, 'quantity': 34000},
#      {'price': 1.65, 'quantity': 34000},
#      {'price': 1.7, 'quantity': 17000},
#      {'price': 1.75, 'quantity': 17000},
#      {'price': 1.9, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 1.5,
#       'bestSell': 1.6,
#       'lastPrice': 1.6},
#      'carry': {'bestBuy': -3450.035462010115,
#       'bestSell': -3388.044514075343,
#       'lastPrice': -3388.044514075343}},
#     'tradeInfo': {'tradedVolume': 80,
#      'value': 21.62,
#      'vmap': 1.59,
#      'premiumTurnover': 837.624,
#      'openInterest': 98,
#      'changeinOpenInterest': 15,
#      'pchangeinOpenInterest': 18.072289156626507,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 47.97,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 54,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE54.00',
#     'openPrice': 1.45,
#     'highPrice': 1.95,
#     'lowPrice': 0.95,
#     'closePrice': 1.15,
#     'prevClose': 1.15,
#     'lastPrice': 1.15,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 78,
#     'totalTurnover': 17.64},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 1275000,
#     'totalSellQuantity': 1003000,
#     'bid': [{'price': 1.05, 'quantity': 17000},
#      {'price': 1, 'quantity': 17000},
#      {'price': 0.95, 'quantity': 34000},
#      {'price': 0.85, 'quantity': 17000},
#      {'price': 0.8, 'quantity': 136000}],
#     'ask': [{'price': 1.2, 'quantity': 17000},
#      {'price': 1.25, 'quantity': 34000},
#      {'price': 1.3, 'quantity': 17000},
#      {'price': 1.35, 'quantity': 34000},
#      {'price': 1.5, 'quantity': 51000}],
#     'carryOfCost': {'price': {'bestBuy': 1.05,
#       'bestSell': 1.2,
#       'lastPrice': 1.15},
#      'carry': {'bestBuy': -48039.99433671604,
#       'bestSell': -46415.362393117684,
#       'lastPrice': -46933.17103521303}},
#     'tradeInfo': {'tradedVolume': 78,
#      'value': 17.64,
#      'vmap': 1.33,
#      'premiumTurnover': 733.6758,
#      'openInterest': 52,
#      'changeinOpenInterest': -15,
#      'pchangeinOpenInterest': -22.388059701492537,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 42.79,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 52,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE52.00',
#     'openPrice': 0.3,
#     'highPrice': 0.3,
#     'lowPrice': 0.15,
#     'closePrice': 0.25,
#     'prevClose': 0.45,
#     'lastPrice': 0.25,
#     'change': -0.2,
#     'pChange': -44.44444444444445,
#     'numberOfContractsTraded': 76,
#     'totalTurnover': 2.58},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 1530000,
#     'totalSellQuantity': 527000,
#     'bid': [{'price': 0.2, 'quantity': 17000},
#      {'price': 0.15, 'quantity': 153000},
#      {'price': 0.1, 'quantity': 442000},
#      {'price': 0.05, 'quantity': 918000},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.25, 'quantity': 34000},
#      {'price': 0.3, 'quantity': 85000},
#      {'price': 0.85, 'quantity': 17000},
#      {'price': 1.9, 'quantity': 391000},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 0.2,
#       'bestSell': 0.25,
#       'lastPrice': 0.25},
#      'carry': {'bestBuy': -0.3027266105324014,
#       'bestSell': -98.29943380850844,
#       'lastPrice': -0.27048608643307437}},
#     'tradeInfo': {'tradedVolume': 76,
#      'value': 2.58,
#      'vmap': 0.2,
#      'premiumTurnover': 674.424,
#      'openInterest': 94,
#      'changeinOpenInterest': -8,
#      'pchangeinOpenInterest': -7.8431372549019605,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 49.72,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 62,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE62.00',
#     'openPrice': 0.1,
#     'highPrice': 0.15,
#     'lowPrice': 0.05,
#     'closePrice': 0.1,
#     'prevClose': 0.15,
#     'lastPrice': 0.1,
#     'change': -0.04999999999999999,
#     'pChange': -33.33333333333333,
#     'numberOfContractsTraded': 72,
#     'totalTurnover': 1.1},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 493000,
#     'totalSellQuantity': 1275000,
#     'bid': [{'price': 0.05, 'quantity': 493000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.1, 'quantity': 102000},
#      {'price': 0.15, 'quantity': 136000},
#      {'price': 0.25, 'quantity': 34000},
#      {'price': 0.3, 'quantity': 85000},
#      {'price': 0.35, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.05,
#       'bestSell': 0.1,
#       'lastPrice': 0.1},
#      'carry': {'bestBuy': -85081.68399568435,
#       'bestSell': -76648.39329887168,
#       'lastPrice': -76648.39329887168}},
#     'tradeInfo': {'tradedVolume': 72,
#      'value': 1.1,
#      'vmap': 0.09,
#      'premiumTurnover': 759.9816,
#      'openInterest': 164,
#      'changeinOpenInterest': -11,
#      'pchangeinOpenInterest': -6.285714285714286,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 88.42,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 55,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE55.00',
#     'openPrice': 3.1,
#     'highPrice': 3.5,
#     'lowPrice': 2.95,
#     'closePrice': 3.1,
#     'prevClose': 3,
#     'lastPrice': 3.1,
#     'change': 0.10000000000000009,
#     'pChange': 3.333333333333336,
#     'numberOfContractsTraded': 57,
#     'totalTurnover': 31.01},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 986000,
#     'totalSellQuantity': 680000,
#     'bid': [{'price': 3.1, 'quantity': 17000},
#      {'price': 3.05, 'quantity': 17000},
#      {'price': 3, 'quantity': 17000},
#      {'price': 2.95, 'quantity': 17000},
#      {'price': 2.9, 'quantity': 34000}],
#     'ask': [{'price': 3.3, 'quantity': 34000},
#      {'price': 3.35, 'quantity': 68000},
#      {'price': 3.4, 'quantity': 17000},
#      {'price': 3.45, 'quantity': 17000},
#      {'price': 3.5, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 3.1,
#       'bestSell': 3.3,
#       'lastPrice': 3.1},
#      'carry': {'bestBuy': -2752.7538666554533,
#       'bestSell': -2692.7014185023295,
#       'lastPrice': -2752.7538666554533}},
#     'tradeInfo': {'tradedVolume': 57,
#      'value': 31.01,
#      'vmap': 3.2,
#      'premiumTurnover': 563.958,
#      'openInterest': 52,
#      'changeinOpenInterest': 33,
#      'pchangeinOpenInterest': 173.68421052631578,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 43.46,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Put',
#     'strikePrice': 50,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021PE50.00',
#     'openPrice': 1.35,
#     'highPrice': 1.45,
#     'lowPrice': 1.15,
#     'closePrice': 1.2,
#     'prevClose': 1.55,
#     'lastPrice': 1.15,
#     'change': -0.40000000000000013,
#     'pChange': -25.806451612903235,
#     'numberOfContractsTraded': 38,
#     'totalTurnover': 8.2},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 510000,
#     'totalSellQuantity': 1088000,
#     'bid': [{'price': 1.1, 'quantity': 51000},
#      {'price': 1.05, 'quantity': 17000},
#      {'price': 1, 'quantity': 51000},
#      {'price': 0.8, 'quantity': 17000},
#      {'price': 0.5, 'quantity': 34000}],
#     'ask': [{'price': 1.15, 'quantity': 51000},
#      {'price': 1.2, 'quantity': 17000},
#      {'price': 1.3, 'quantity': 17000},
#      {'price': 1.35, 'quantity': 51000},
#      {'price': 1.4, 'quantity': 51000}],
#     'carryOfCost': {'price': {'bestBuy': 1.1,
#       'bestSell': 1.15,
#       'lastPrice': 1.15},
#      'carry': {'bestBuy': -3747.9474326177506,
#       'bestSell': -3705.2503448852394,
#       'lastPrice': -3705.2503448852394}},
#     'tradeInfo': {'tradedVolume': 38,
#      'value': 8.2,
#      'vmap': 1.27,
#      'premiumTurnover': 331.2042,
#      'openInterest': 78,
#      'changeinOpenInterest': 13,
#      'pchangeinOpenInterest': 20,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 44.53,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 69,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE69.00',
#     'openPrice': 0.05,
#     'highPrice': 0.05,
#     'lowPrice': 0.05,
#     'closePrice': 0.05,
#     'prevClose': 0.05,
#     'lastPrice': 0.05,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 38,
#     'totalTurnover': 0.32},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 0,
#     'totalSellQuantity': 1479000,
#     'bid': [{'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.05, 'quantity': 85000},
#      {'price': 0.1, 'quantity': 1003000},
#      {'price': 0.15, 'quantity': 119000},
#      {'price': 0.2, 'quantity': 51000},
#      {'price': 0.25, 'quantity': 34000}],
#     'carryOfCost': {'price': {'bestBuy': 0,
#       'bestSell': 0.05,
#       'lastPrice': 0.05},
#      'carry': {'bestBuy': 0,
#       'bestSell': -85081.68399568435,
#       'lastPrice': -85081.68399568435}},
#     'tradeInfo': {'tradedVolume': 38,
#      'value': 0.32,
#      'vmap': 0.05,
#      'premiumTurnover': 446.063,
#      'openInterest': 267,
#      'changeinOpenInterest': -19,
#      'pchangeinOpenInterest': -6.643356643356643,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 126.99,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 51,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE51.00',
#     'openPrice': 0.15,
#     'highPrice': 0.15,
#     'lowPrice': 0.1,
#     'closePrice': 0.15,
#     'prevClose': 0.3,
#     'lastPrice': 0.15,
#     'change': -0.15,
#     'pChange': -50,
#     'numberOfContractsTraded': 35,
#     'totalTurnover': 0.77},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 731000,
#     'totalSellQuantity': 765000,
#     'bid': [{'price': 0.1, 'quantity': 51000},
#      {'price': 0.05, 'quantity': 680000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.15, 'quantity': 85000},
#      {'price': 0.2, 'quantity': 68000},
#      {'price': 0.25, 'quantity': 34000},
#      {'price': 0.3, 'quantity': 102000},
#      {'price': 1.5, 'quantity': 51000}],
#     'carryOfCost': {'price': {'bestBuy': 0.1,
#       'bestSell': 0.15,
#       'lastPrice': 0.15},
#      'carry': {'bestBuy': -76648.39329887168,
#       'bestSell': -71715.23448355569,
#       'lastPrice': -71715.23448355569}},
#     'tradeInfo': {'tradedVolume': 35,
#      'value': 0.77,
#      'vmap': 0.13,
#      'premiumTurnover': 304.2235,
#      'openInterest': 31,
#      'changeinOpenInterest': -14,
#      'pchangeinOpenInterest': -31.11111111111111,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 58.3,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Put',
#     'strikePrice': 46,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021PE46.00',
#     'openPrice': 0.35,
#     'highPrice': 0.95,
#     'lowPrice': 0.35,
#     'closePrice': 0.65,
#     'prevClose': 1.1,
#     'lastPrice': 0.65,
#     'change': -0.45000000000000007,
#     'pChange': -40.909090909090914,
#     'numberOfContractsTraded': 28,
#     'totalTurnover': 1.86},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 170000,
#     'totalSellQuantity': 901000,
#     'bid': [{'price': 0.35, 'quantity': 68000},
#      {'price': 0.3, 'quantity': 17000},
#      {'price': 0.15, 'quantity': 17000},
#      {'price': 0.1, 'quantity': 68000},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.75, 'quantity': 17000},
#      {'price': 0.8, 'quantity': 17000},
#      {'price': 1, 'quantity': 17000},
#      {'price': 1.05, 'quantity': 17000},
#      {'price': 1.4, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.35,
#       'bestSell': 0.75,
#       'lastPrice': 0.65},
#      'carry': {'bestBuy': -4847.877145961424,
#       'bestSell': -4115.821569653222,
#       'lastPrice': -4253.273695781763}},
#     'tradeInfo': {'tradedVolume': 28,
#      'value': 1.86,
#      'vmap': 0.39,
#      'premiumTurnover': 220.8164,
#      'openInterest': 29,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 3.5714285714285716,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 52.74,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 65,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE65.00',
#     'openPrice': 0.05,
#     'highPrice': 0.1,
#     'lowPrice': 0.05,
#     'closePrice': 0.1,
#     'prevClose': 0.1,
#     'lastPrice': 0.05,
#     'change': -0.05,
#     'pChange': -50,
#     'numberOfContractsTraded': 28,
#     'totalTurnover': 0.24},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 1853000,
#     'totalSellQuantity': 2890000,
#     'bid': [{'price': 0.05, 'quantity': 1853000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.1, 'quantity': 1241000},
#      {'price': 0.15, 'quantity': 578000},
#      {'price': 0.2, 'quantity': 255000},
#      {'price': 0.35, 'quantity': 34000},
#      {'price': 0.4, 'quantity': 34000}],
#     'carryOfCost': {'price': {'bestBuy': 0.05,
#       'bestSell': 0.1,
#       'lastPrice': 0.05},
#      'carry': {'bestBuy': -85081.68399568435,
#       'bestSell': -76648.39329887168,
#       'lastPrice': -85081.68399568435}},
#     'tradeInfo': {'tradedVolume': 28,
#      'value': 0.24,
#      'vmap': 0.05,
#      'premiumTurnover': 309.638,
#      'openInterest': 438,
#      'changeinOpenInterest': -21,
#      'pchangeinOpenInterest': -4.57516339869281,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 112.76,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Put',
#     'strikePrice': 45,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021PE45.00',
#     'openPrice': 0.45,
#     'highPrice': 0.55,
#     'lowPrice': 0.35,
#     'closePrice': 0.35,
#     'prevClose': 0.5,
#     'lastPrice': 0.35,
#     'change': -0.15000000000000002,
#     'pChange': -30.000000000000004,
#     'numberOfContractsTraded': 26,
#     'totalTurnover': 1.86},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 646000,
#     'totalSellQuantity': 1462000,
#     'bid': [{'price': 0.35, 'quantity': 34000},
#      {'price': 0.3, 'quantity': 51000},
#      {'price': 0.25, 'quantity': 17000},
#      {'price': 0.2, 'quantity': 17000},
#      {'price': 0.05, 'quantity': 527000}],
#     'ask': [{'price': 0.4, 'quantity': 17000},
#      {'price': 0.45, 'quantity': 85000},
#      {'price': 0.5, 'quantity': 17000},
#      {'price': 0.55, 'quantity': 17000},
#      {'price': 0.6, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.35,
#       'bestSell': 0.4,
#       'lastPrice': 0.35},
#      'carry': {'bestBuy': -4847.877145961424,
#       'bestSell': -4719.616729361554,
#       'lastPrice': -4847.877145961424}},
#     'tradeInfo': {'tradedVolume': 26,
#      'value': 1.86,
#      'vmap': 0.42,
#      'premiumTurnover': 200.7564,
#      'openInterest': 24,
#      'changeinOpenInterest': 9,
#      'pchangeinOpenInterest': 60,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 47.76,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 53,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE53.00',
#     'openPrice': 2.1,
#     'highPrice': 2.35,
#     'lowPrice': 1.65,
#     'closePrice': 1.8,
#     'prevClose': 1.65,
#     'lastPrice': 1.95,
#     'change': 0.30000000000000004,
#     'pChange': 18.181818181818183,
#     'numberOfContractsTraded': 23,
#     'totalTurnover': 7.82},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 663000,
#     'totalSellQuantity': 510000,
#     'bid': [{'price': 1.65, 'quantity': 17000},
#      {'price': 1.6, 'quantity': 34000},
#      {'price': 1.3, 'quantity': 17000},
#      {'price': 1.05, 'quantity': 17000},
#      {'price': 0.7, 'quantity': 17000}],
#     'ask': [{'price': 1.9, 'quantity': 34000},
#      {'price': 2, 'quantity': 34000},
#      {'price': 2.05, 'quantity': 34000},
#      {'price': 3.4, 'quantity': 17000},
#      {'price': 3.8, 'quantity': 391000}],
#     'carryOfCost': {'price': {'bestBuy': 1.65,
#       'bestSell': 1.9,
#       'lastPrice': 1.95},
#      'carry': {'bestBuy': -42540.84199784217,
#       'bestSell': -40824.38571901333,
#       'lastPrice': -40508.35063444032}},
#     'tradeInfo': {'tradedVolume': 23,
#      'value': 7.82,
#      'vmap': 2,
#      'premiumTurnover': 215.05,
#      'openInterest': 31,
#      'changeinOpenInterest': -2,
#      'pchangeinOpenInterest': -6.0606060606060606,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 57.61,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 68,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE68.00',
#     'openPrice': 0.05,
#     'highPrice': 0.05,
#     'lowPrice': 0.05,
#     'closePrice': 0.05,
#     'prevClose': 0.05,
#     'lastPrice': 0.05,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 23,
#     'totalTurnover': 0.2},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 0,
#     'totalSellQuantity': 1258000,
#     'bid': [{'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.05, 'quantity': 136000},
#      {'price': 0.1, 'quantity': 1037000},
#      {'price': 0.5, 'quantity': 51000},
#      {'price': 0.95, 'quantity': 17000},
#      {'price': 1, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0,
#       'bestSell': 0.05,
#       'lastPrice': 0.05},
#      'carry': {'bestBuy': 0,
#       'bestSell': -85081.68399568435,
#       'lastPrice': -85081.68399568435}},
#     'tradeInfo': {'tradedVolume': 23,
#      'value': 0.2,
#      'vmap': 0.05,
#      'premiumTurnover': 266.0755,
#      'openInterest': 63,
#      'changeinOpenInterest': -19,
#      'pchangeinOpenInterest': -23.170731707317074,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 120.48,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 64,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE64.00',
#     'openPrice': 0.05,
#     'highPrice': 0.1,
#     'lowPrice': 0.05,
#     'closePrice': 0.1,
#     'prevClose': 0.1,
#     'lastPrice': 0.1,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 22,
#     'totalTurnover': 0.22},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 425000,
#     'totalSellQuantity': 1190000,
#     'bid': [{'price': 0.05, 'quantity': 425000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.1, 'quantity': 391000},
#      {'price': 0.15, 'quantity': 119000},
#      {'price': 0.3, 'quantity': 153000},
#      {'price': 1, 'quantity': 34000},
#      {'price': 1.1, 'quantity': 51000}],
#     'carryOfCost': {'price': {'bestBuy': 0.05,
#       'bestSell': 0.1,
#       'lastPrice': 0.1},
#      'carry': {'bestBuy': -85081.68399568435,
#       'bestSell': -76648.39329887168,
#       'lastPrice': -76648.39329887168}},
#     'tradeInfo': {'tradedVolume': 22,
#      'value': 0.22,
#      'vmap': 0.06,
#      'premiumTurnover': 239.5844,
#      'openInterest': 197,
#      'changeinOpenInterest': -16,
#      'pchangeinOpenInterest': -7.511737089201878,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 92.71,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 59,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE59.00',
#     'openPrice': 0.2,
#     'highPrice': 0.2,
#     'lowPrice': 0.1,
#     'closePrice': 0.15,
#     'prevClose': 0.25,
#     'lastPrice': 0.15,
#     'change': -0.1,
#     'pChange': -40,
#     'numberOfContractsTraded': 22,
#     'totalTurnover': 0.56},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 1700000,
#     'totalSellQuantity': 1734000,
#     'bid': [{'price': 0.1, 'quantity': 578000},
#      {'price': 0.05, 'quantity': 1122000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.15, 'quantity': 68000},
#      {'price': 0.2, 'quantity': 187000},
#      {'price': 0.25, 'quantity': 85000},
#      {'price': 0.5, 'quantity': 136000},
#      {'price': 0.8, 'quantity': 442000}],
#     'carryOfCost': {'price': {'bestBuy': 0.1,
#       'bestSell': 0.15,
#       'lastPrice': 0.15},
#      'carry': {'bestBuy': -76648.39329887168,
#       'bestSell': -71715.23448355569,
#       'lastPrice': -71715.23448355569}},
#     'tradeInfo': {'tradedVolume': 22,
#      'value': 0.56,
#      'vmap': 0.15,
#      'premiumTurnover': 221.221,
#      'openInterest': 104,
#      'changeinOpenInterest': -4,
#      'pchangeinOpenInterest': -3.7037037037037037,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 67.68,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 61,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE61.00',
#     'openPrice': 0.1,
#     'highPrice': 0.15,
#     'lowPrice': 0.1,
#     'closePrice': 0.1,
#     'prevClose': 0.2,
#     'lastPrice': 0.1,
#     'change': -0.1,
#     'pChange': -50,
#     'numberOfContractsTraded': 19,
#     'totalTurnover': 0.32},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 833000,
#     'totalSellQuantity': 782000,
#     'bid': [{'price': 0.1, 'quantity': 34000},
#      {'price': 0.05, 'quantity': 799000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.15, 'quantity': 204000},
#      {'price': 0.2, 'quantity': 17000},
#      {'price': 0.3, 'quantity': 17000},
#      {'price': 0.4, 'quantity': 136000},
#      {'price': 1, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.1,
#       'bestSell': 0.15,
#       'lastPrice': 0.1},
#      'carry': {'bestBuy': -76648.39329887168,
#       'bestSell': -71715.23448355569,
#       'lastPrice': -76648.39329887168}},
#     'tradeInfo': {'tradedVolume': 19,
#      'value': 0.32,
#      'vmap': 0.1,
#      'premiumTurnover': 197.353,
#      'openInterest': 106,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 87.29,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 65,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE65.00',
#     'openPrice': 0.7,
#     'highPrice': 0.8,
#     'lowPrice': 0.6,
#     'closePrice': 0.65,
#     'prevClose': 0.7,
#     'lastPrice': 0.65,
#     'change': -0.04999999999999993,
#     'pChange': -7.142857142857134,
#     'numberOfContractsTraded': 19,
#     'totalTurnover': 2.16},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 476000,
#     'totalSellQuantity': 986000,
#     'bid': [{'price': 0.6, 'quantity': 51000},
#      {'price': 0.55, 'quantity': 17000},
#      {'price': 0.5, 'quantity': 34000},
#      {'price': 0.25, 'quantity': 17000},
#      {'price': 0.2, 'quantity': 17000}],
#     'ask': [{'price': 0.65, 'quantity': 17000},
#      {'price': 0.7, 'quantity': 68000},
#      {'price': 0.8, 'quantity': 34000},
#      {'price': 0.85, 'quantity': 34000},
#      {'price': 0.9, 'quantity': 17000}],
#     'carryOfCost': {'price': {'bestBuy': 0.6,
#       'bestSell': 0.65,
#       'lastPrice': 0.65},
#      'carry': {'bestBuy': -4330.156822889238,
#       'bestSell': -4253.273695781763,
#       'lastPrice': -4253.273695781763}},
#     'tradeInfo': {'tradedVolume': 19,
#      'value': 2.16,
#      'vmap': 0.67,
#      'premiumTurnover': 212.1141,
#      'openInterest': 18,
#      'changeinOpenInterest': 13,
#      'pchangeinOpenInterest': 260,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 48.19,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
# ...
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 14.85,
#       'bestSell': 21.15,
#       'lastPrice': 0},
#      'carry': {'bestBuy': -1247.9954979145928,
#       'bestSell': -908.3149329437873,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 39,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE39.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 0,
#     'prevClose': 9.8,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 391000,
#     'totalSellQuantity': 391000,
#     'bid': [{'price': 13.9, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 20.05, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 13.9,
#       'bestSell': 20.05,
#       'lastPrice': 0},
#      'carry': {'bestBuy': -1311.4968772985474,
#       'bestSell': -959.6173655358758,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 29,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE29.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 0,
#     'prevClose': 18.4,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 391000,
#     'totalSellQuantity': 391000,
#     'bid': [{'price': 22.85, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 31.15, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 22.85,
#       'bestSell': 31.15,
#       'lastPrice': 0},
#      'carry': {'bestBuy': -834.0554794582786,
#       'bestSell': -536.4237908239742,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 38,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE38.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 0,
#     'prevClose': 1.85,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 0,
#     'totalSellQuantity': 51000,
#     'bid': [{'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 0.1, 'quantity': 17000},
#      {'price': 0.5, 'quantity': 34000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 0, 'bestSell': 0.1, 'lastPrice': 0},
#      'carry': {'bestBuy': 0, 'bestSell': -76648.39329887168, 'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Call',
#     'strikePrice': 39,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021CE39.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 0,
#     'prevClose': 6.65,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 476000,
#     'totalSellQuantity': 391000,
#     'bid': [{'price': 13.8, 'quantity': 391000},
#      {'price': 9.25, 'quantity': 85000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 17.95, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 13.8,
#       'bestSell': 17.95,
#       'lastPrice': 0},
#      'carry': {'bestBuy': -16700.14012945903,
#       'bestSell': -13501.261602410294,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 47,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE47.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 0,
#     'prevClose': 5.05,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 425000,
#     'totalSellQuantity': 425000,
#     'bid': [{'price': 6.25, 'quantity': 34000},
#      {'price': 6.2, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 10.35, 'quantity': 34000},
#      {'price': 10.4, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 6.25,
#       'bestSell': 10.35,
#       'lastPrice': 0},
#      'carry': {'bestBuy': -2079.252646724186,
#       'bestSell': -1594.758316654397,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '29-Apr-2021',
#     'optionType': 'Call',
#     'strikePrice': 54,
#     'identifier': 'OPTSTKNATIONALUM29-04-2021CE54.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 0,
#     'prevClose': 2.55,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 119000,
#     'totalSellQuantity': 510000,
#     'bid': [{'price': 2.85, 'quantity': 34000},
#      {'price': 2.65, 'quantity': 17000},
#      {'price': 0.55, 'quantity': 68000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'ask': [{'price': 5.15, 'quantity': 17000},
#      {'price': 5.2, 'quantity': 17000},
#      {'price': 5.7, 'quantity': 391000},
#      {'price': 9.6, 'quantity': 85000},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 2.85,
#       'bestSell': 5.15,
#       'lastPrice': 0},
#      'carry': {'bestBuy': -2833.517913449789,
#       'bestSell': -2265.195892543983,
#       'lastPrice': 0}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}},
#   {'metadata': {'instrumentType': 'Stock Options',
#     'expiryDate': '25-Mar-2021',
#     'optionType': 'Put',
#     'strikePrice': 61,
#     'identifier': 'OPTSTKNATIONALUM25-03-2021PE61.00',
#     'openPrice': 0,
#     'highPrice': 0,
#     'lowPrice': 0,
#     'closePrice': 8.1,
#     'prevClose': 8.1,
#     'lastPrice': 8.1,
#     'change': 0,
#     'pChange': 0,
#     'numberOfContractsTraded': 0,
#     'totalTurnover': 0},
#    'underlyingValue': 54.45,
#    'volumeFreezeQuantity': 850001,
#    'marketDeptOrderBook': {'totalBuyQuantity': 527000,
#     'totalSellQuantity': 408000,
#     'bid': [{'price': 6.5, 'quantity': 17000},
#      {'price': 6.45, 'quantity': 17000},
#      {'price': 6.4, 'quantity': 17000},
#      {'price': 4.2, 'quantity': 391000},
#      {'price': 1.65, 'quantity': 17000}],
#     'ask': [{'price': 6.8, 'quantity': 17000},
#      {'price': 8.35, 'quantity': 391000},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0},
#      {'price': 0, 'quantity': 0}],
#     'carryOfCost': {'price': {'bestBuy': 6.5,
#       'bestSell': 6.8,
#       'lastPrice': 8.1},
#      'carry': {'bestBuy': -25860.01484847477,
#       'bestSell': -25311.04955256239,
#       'lastPrice': -23182.595250357015}},
#     'tradeInfo': {'tradedVolume': 0,
#      'value': 0,
#      'vmap': 0,
#      'premiumTurnover': 0,
#      'openInterest': 32,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'marketLot': 17000},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.78,
#      'annualisedVolatility': 53.2,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 180964897}}}],
#  'strikePrices': [0,
#   0,
#   0,
#   25,
#   25,
#   26,
#   26,
#   27,
#   27,
#   28,
#   28,
#   29,
#   29,
#   29,
#   29,
#   30,
#   30,
#   30,
#   30,
#   31,
#   31,
#   31,
#   31,
#   32,
#   32,
#   32,
#   32,
#   33,
#   33,
#   33,
#   33,
#   34,
#   34,
#   34,
#   34,
#   35,
#   35,
#   35,
#   35,
#   36,
#   36,
#   36,
#   36,
#   37,
#   37,
#   37,
#   37,
#   38,
#   38,
#   38,
#   38,
#   39,
#   39,
#   39,
#   39,
#   40,
#   40,
#   40,
#   40,
#   40,
#   41,
#   41,
#   41,
#   41,
#   42,
#   42,
#   42,
#   42,
#   43,
#   43,
#   43,
#   43,
#   44,
#   44,
#   44,
#   44,
#   45,
#   45,
#   45,
#   45,
#   45,
#   46,
#   46,
#   46,
#   46,
#   47,
#   47,
#   47,
#   47,
#   48,
#   48,
#   48,
#   48,
#   49,
#   49,
#   49,
#   49,
#   50,
#   50,
#   50,
#   50,
#   51,
#   51,
#   51,
#   51,
#   52,
#   52,
#   52,
#   52,
#   53,
#   53,
#   53,
#   53,
#   54,
#   54,
#   54,
#   54,
#   55,
#   55,
#   55,
#   55,
#   56,
#   56,
#   56,
#   56,
#   57,
#   57,
#   57,
#   57,
#   58,
#   58,
#   58,
#   58,
#   59,
#   59,
#   59,
#   59,
#   60,
#   60,
#   60,
#   60,
#   60,
#   61,
#   61,
#   61,
#   61,
#   62,
#   62,
#   62,
#   62,
#   63,
#   63,
#   63,
#   63,
#   64,
#   64,
#   64,
#   64,
#   65,
#   65,
#   65,
#   65,
#   66,
#   66,
#   66,
#   66,
#   67,
#   67,
#   67,
#   67,
#   68,
#   68,
#   68,
#   68,
#   69,
#   69,
#   69,
#   69,
#   70,
#   70,
#   70,
#   70,
#   71,
#   71,
#   71,
#   71],
#  'expiryDates': ['25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '25-Mar-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '29-Apr-2021',
#   '27-May-2021',
#   '27-May-2021',
#   '27-May-2021',
#   '27-May-2021']}
